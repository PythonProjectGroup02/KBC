# %% [markdown]
# # 월별 순위 API
#
# ## 팀 이름
# 두산, 롯데, 삼성, 키움, 한화, KIA, KT, LG, NC, SSG
#
# <br>
#
# ----
#
# <br>
#
# > 필요한 데이터 : Data/rank/*.csv

# %%
def teamRanking() :
    import pandas as pd
    # 사용자가 선택하는 값
    select_year = '2022'
    select_month = '04'
    team_name = '두산'

    # ------

    # 서버에서 불러와 원하는 값 추출
    team_df = pd.read_csv(f'./Data/rank/{team_name}_rank.csv')
    team_df.날짜 = pd.to_datetime(team_df.날짜)
    result_df = team_df[(team_df.날짜.dt.year == int(select_year)) & (team_df.날짜.dt.month == int(select_month))]
    result_df.loc[:, '날짜'] = result_df.날짜.astype(str)

    response = {}

    response['rank'] = []
    response['info'] = []

    for i,j in zip(result_df.to_dict()['날짜'].values(), result_df.to_dict()['순위'].values()) :
        result_dict = {
            '날짜' : i,
            '순위' : j
        }
        response['rank'].append(result_dict)


    for index in range(len(result_df.index)) :
        response['info'].append(result_df.loc[index, ['날짜', '총 경기수', '승리', '패배', '무승부', '승률', '게임차', '최근 10경기 전적', '연속 승패 현황', '홈 경기 전적', '원정 경기 전적']].to_dict())

    # return
    return response

# %%
result = teamRanking()

print(result)
# Out:
# {'rank': [{'날짜': Timestamp('2022-04-02 00:00:00'), '순위': 1}, {'날짜': Timestamp('2022-04-03 00:00:00'), '순위': 1}, {'날짜': Timestamp('2022-04-05 00:00:00'), '순위': 3}, {'날짜': Timestamp('2022-04-06 00:00:00'), '순위': 4}, {'날짜': Timestamp('2022-04-07 00:00:00'), '순위': 3}, {'날짜': Timestamp('2022-04-08 00:00:00'), '순위': 3}, {'날짜': Timestamp('2022-04-09 00:00:00'), '순위': 3}, {'날짜': Timestamp('2022-04-10 00:00:00'), '순위': 3}, {'날짜': Timestamp('2022-04-12 00:00:00'), '순위': 3}, {'날짜': Timestamp('2022-04-13 00:00:00'), '순위': 3}, {'날짜': Timestamp('2022-04-14 00:00:00'), '순위': 3}, {'날짜': Timestamp('2022-04-15 00:00:00'), '순위': 4}, {'날짜': Timestamp('2022-04-16 00:00:00'), '순위': 3}, {'날짜': Timestamp('2022-04-17 00:00:00'), '순위': 4}, {'날짜': Timestamp('2022-04-19 00:00:00'), '순위': 4}, {'날짜': Timestamp('2022-04-20 00:00:00'), '순위': 4}, {'날짜': Timestamp('2022-04-21 00:00:00'), '순위': 2}, {'날짜': Timestamp('2022-04-22 00:00:00'), '순위': 3}, {'날짜': Timestamp('2022-04-23 00:00:00'), '순위': 2}, {'날짜': Timestamp('2022-04-24 00:00:00'), '순위': 3}, {'날짜': Timestamp('2022-04-26 00:00:00'), '순위': 2}, {'날짜': Timestamp('2022-04-27 00:00:00'), '순위': 2}, {'날짜': Timestamp('2022-04-28 00:00:00'), '순위': 3}, {'날짜': Timestamp('2022-04-29 00:00:00'), '순위': 4}, {'날짜': Timestamp('2022-04-30 00:00:00'), '순위': 5}], 'info': [{'날짜': Timestamp('2022-04-02 00:00:00'), '총 경기수': 1, '승리': 1, '패배': 0, '무승부': 0, '승률': 1.0, '게임차': 0.0, '최근 10경기 전적': '1승0무0패', '연속 승패 현황': '1승', '홈 경기 전적': '1-0-0', '원정 경기 전적': '0-0-0'}, {'날짜': Timestamp('2022-04-03 00:00:00'), '총 경기수': 2, '승리': 2, '패배': 0, '무승부': 0, '승률': 1.0, '게임차': 0.0, '최근 10경기 전적': '2승0무0패', '연속 승
': 7, '패배': 4, '무승부': 0, '승률': 0.636, '게임차': 3.5, '최근 10경기 전적': '6승0무4패', '연속 승패 현황': '1패', '홈 경기 전적': '3-0-3', '원정 경기 전적': '4-0-1'}, {'날짜': Timestamp('2022-04-16 00:00:00'), '총 경기수': 12, '승리': 8, '패배': 4, '무승부': 0, '승률': 0.667, '게임차': 3.5, '최근 10경기 전적': '6승0무4패', '연속 승패 현황': '1승', '홈 경기 전적': '4-0-3', '원정 경기 전적': '4-0-1'}, {'날짜': Timestamp('2022-04-17 00:00:00'), '총 경기수': 13, '승리': 8, '패배': 5, '무승부': 0, '승률': 0.615, '게임차': 4.5, '최근 10경기 전적': '6승0무4패', '연속 승패 현황': '1패', '홈 경기 전적': '4-0-4', '원정 경기 전적': '4-0-1'}, {'날짜': Timestamp('2022-04-19 00:00:00'), '총 경기수': 1 ...

# %%
import pandas as pd
# 사용자가 선택하는 값
select_year = '2022'
select_month = '04'
team_name = '두산'

# ------

# 서버에서 불러와 원하는 값 추출
team_df = pd.read_csv(f'./Data/rank/{team_name}_rank.csv')
team_df.날짜 = pd.to_datetime(team_df.날짜)
result_df = team_df[(team_df.날짜.dt.year == int(select_year)) & (team_df.날짜.dt.month == int(select_month))]
result_df.loc[:, '날짜'] = result_df.날짜.astype(str)

# %%
# Last 10 Games Record , Streak Record , Home Games  Away Games

# %%
team_df
# Out:
#           date teamname  rank  totalgames  win  loss  draw  winningrate  \
# 0   2022-04-02       두산     1           1    1     0     0        1.000
# 1   2022-04-03       두산     1           2    2     0     0        1.000
# 2   2022-04-05       두산     3           3    2     1     0        0.667
# 3   2022-04-06       두산     4           4    2     2     0        0.500
# 4   2022-04-07       두산     3           5    3     2     0        0.600
# ..         ...      ...   ...         ...  ...   ...   ...          ...
# 383 2024-05-30       두산     2          58   32    24     2        0.571
# 384 2024-05-31       두산     3          59   32    25     2        0.561
# 385 2024-06-01       두산     4          60   32    26     2        0.552
# 386 2024-06-02       두산     4          61   32    27     2        0.542
# 387 2024-06-04       두산     4          62   33    27     2        0.550
#
#      gamesbehind 10gamesrecord streak     home     away
# 0            0.0        1승0무0패     1승    1-0-0    0-0-0
# 1            0.0        2승0무0패     2승    2-0-0    0-0-0
# 2            1.0        2승0무1패     1패    2-0-1    0-0-0
# 3            2.0        2승0무2패     2패    2-0-2    0-0-0
# 4            2.0        3승0무2패     1승    3-0-2    0-0-0
# ..           ...           ...    ...      ...      ...
# 383          3.0        6승1무3패     2승  19-1-10  13-1-14
# 384          3.0        6승0무4패     1패  19-1-11  13-1-14
# 385          4.0        5승0무5패     2패  19-1-12  13-1-14
# 386          4.0        4승0무6패     3패  19-1-13  13-1-14
# 387          3.0        4승0무6패     1승  19-1-13  14-1-14
#
# [388 rows x 13 columns]
