# %% [markdown]
# # 데이터 분석
# > 1. 각 컬럼별 관중 수 관계 파악하기
# > 2. 컬럼별 관중 수 평균으로 군집화
# > 3. 상관계수 확인하기

# %%
# 계산
import pandas as pd
import numpy as np

# 차트
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 차트 경고 메세지 무시
import warnings
warnings.filterwarnings('ignore')

# %%
# 한글 폰트 문제 해결 함수
def fontKorea():
    # 한글 폰트 문제 해결 
    # matplotlib은 한글 폰트를 지원하지 않음
    # os정보
    import platform

    # font_manager : 폰트 관리 모듈
    # rc : 폰트 변경 모듈
    from matplotlib import font_manager, rc
    # unicode 설정
    plt.rcParams['axes.unicode_minus'] = False

    if platform.system() == 'Darwin':
        rc('font', family='AppleGothic') # os가 macos
    elif platform.system() == 'Windows':
        path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
        font_name = font_manager.FontProperties(fname=path).get_name()
        rc('font', family=font_name)
    else:
        print("Unknown System")

# %%
# 데이터 열기
kiwoom_new = pd.read_csv('./Data/kiwoom_new.csv')
kiwoom_new.head()
# Out:
#            날짜  팀명  순위  총 경기수  승리  패배  무승부     승률  게임차 최근 10경기 전적  ...  홈팀 원정팀  \
# 0  2022-04-02  키움   6      1   0   1    0  0.000  1.0     0승0무1패  ...  키움  롯데
# 1  2022-04-03  키움   4      2   1   1    0  0.500  1.0     1승0무1패  ...  키움  롯데
# 2  2022-04-05  키움   6      3   1   2    0  0.333  2.0     1승0무2패  ...  키움  LG
# 3  2022-04-06  키움   7      4   1   3    0  0.250  3.0     1승0무3패  ...  키움  LG
# 4  2022-04-07  키움   7      5   1   4    0  0.200  4.0     1승0무4패  ...  키움  LG
#
#    장소  관중 수   시작시간   종료시간  경기시간  홈팀 선발 어웨이팀 선발  구장
# 0  고척  8257  14:00  17:12  3:12    안우진      반즈  고척
# 1  고척  6115  14:00  17:55  3:55    요키시     박세웅  고척
# 2  고척  2298  18:30  21:34  3:04    애플러     임찬규  고척
# 3  고척  2304  18:30  22:13  3:43    최원태     손주영  고척
# 4  고척  2055  18:30  21:01  2:31    정찬헌     김윤식  고척
#
# [5 rows x 24 columns]

# %%
kiwoom_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   날짜          171 non-null    object
#  1   팀명          171 non-null    object
#  2   순위          171 non-null    int64
#  3   총 경기수       171 non-null    int64
#  4   승리          171 non-null    int64
#  5   패배          171 non-null    int64
#  6   무승부         171 non-null    int64
#  7   승률          171 non-null    float64
#  8   게임차         171 non-null    float64
#  9   최근 10경기 전적  171 non-null    object
#  10  연속 승패 현황    171 non-null    object
#  11  홈 경기 전적     171 non-null    object
#  12  원정 경기 전적    171 non-null    object
#  13  요일          171 non-null    object
#  14  홈팀          171 non-null    object
#  15  원정팀         171 non-null    object
#  16  장소          171 non-null    object
#  17  관중 수        171 non-null    int64
#  18  시작시간        171 non-null    object
#  19  종료시간        171 non-null    object
#  20  경기시간        171 non-null    object
#  21  홈팀 선발       171 non-null    object
#  22  어웨이팀 선발     171 non-null    object
#  23  구장          171 non-null    object
# dtypes: float64(2), int64(6), object(16)
# memory usage: 32.2+ KB

# %% [markdown]
# ----
# ## 필요 데이터 선별
# ----

# %%
# 날짜 데이터 타입 변환
kiwoom_new['날짜'] = kiwoom_new['날짜'].astype('datetime64[ns]')
kiwoom_new
# Out:
#             날짜  팀명  순위  총 경기수  승리  패배  무승부     승률   게임차 최근 10경기 전적  ...  홈팀  \
# 0   2022-04-02  키움   6      1   0   1    0  0.000   1.0     0승0무1패  ...  키움
# 1   2022-04-03  키움   4      2   1   1    0  0.500   1.0     1승0무1패  ...  키움
# 2   2022-04-05  키움   6      3   1   2    0  0.333   2.0     1승0무2패  ...  키움
# 3   2022-04-06  키움   7      4   1   3    0  0.250   3.0     1승0무3패  ...  키움
# 4   2022-04-07  키움   7      5   1   4    0  0.200   4.0     1승0무4패  ...  키움
# ..         ...  ..  ..    ...  ..  ..  ...    ...   ...        ...  ...  ..
# 166 2024-05-19  키움   7     45  19  26    0  0.422  10.0     4승0무6패  ...  키움
# 167 2024-05-21  키움   8     46  19  27    0  0.413  10.0     4승0무6패  ...  키움
# 168 2024-05-22  키움   8     47  19  28    0  0.404  10.0     4승0무6패  ...  키움
# 169 2024-05-23  키움   8     48  20  28    0  0.417   9.0     5승0무5패  ...  키움
# 170 2024-05-31  키움   9     54  22  32    0  0.407  11.5     4승0무6패  ...  키움
#
#      원정팀  장소   관중 수   시작시간   종료시간  경기시간  홈팀 선발 어웨이팀 선발  구장
# 0     롯데  고척   8257  14:00  17:12  3:12    안우진      반즈  고척
# 1     롯데  고척   6115  14:00  17:55  3:55    요키시     박세웅  고척
# 2     LG  고척   2298  18:30  21:34  3:04    애플러     임찬규  고척
# 3     LG  고척   2304  18:30  22:13  3:43    최원태     손주영  고척
# 4     LG  고척   2055  18:30  21:01  2:31    정찬헌     김윤식  고척
# ..   ...  ..    ...    ...    ...   ...    ...     ...  ..
# 166  SSG  고척  10049  14:01  17:13  3:12    김인범     오원석  고척
# 167   NC  고척   3940  18:31  21:53  3:22    하영민     신민혁  고척
# 168   NC  고척   4337  18:31  21:54  3:23    후라도      하트  고척
# 169   NC  고척   3897  18:30  21:14  2:44   헤이수스     김시훈  고척
# 170  SSG  고척   5680  18:30  21:23  2:53    김인범     오원석  고척
#
# [171 rows x 24 columns]

# %%
kiwoom_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   날짜          171 non-null    datetime64[ns]
#  1   팀명          171 non-null    object
#  2   순위          171 non-null    int64
#  3   총 경기수       171 non-null    int64
#  4   승리          171 non-null    int64
#  5   패배          171 non-null    int64
#  6   무승부         171 non-null    int64
#  7   승률          171 non-null    float64
#  8   게임차         171 non-null    float64
#  9   최근 10경기 전적  171 non-null    object
#  10  연속 승패 현황    171 non-null    object
#  11  홈 경기 전적     171 non-null    object
#  12  원정 경기 전적    171 non-null    object
#  13  요일          171 non-null    object
#  14  홈팀          171 non-null    object
#  15  원정팀         171 non-null    object
#  16  장소          171 non-null    object
#  17  관중 수        171 non-null    int64
#  18  시작시간        171 non-null    object
#  19  종료시간        171 non-null    object
#  20  경기시간        171 non-null    object
#  21  홈팀 선발       171 non-null    object
#  22  어웨이팀 선발     171 non-null    object
#  23  구장          171 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(6), object(15)
# memory usage: 32.2+ KB

# %%
# 해당 열들은 목표로 하는 분석 내용과 상관이 없는 데이터 -> 삭제
kiwoom_new = kiwoom_new.drop(['팀명','홈팀','장소','구장','홈팀 선발','어웨이팀 선발'],axis=1)
kiwoom_new
# Out:
#             날짜  순위  총 경기수  승리  패배  무승부     승률   게임차 최근 10경기 전적 연속 승패 현황  \
# 0   2022-04-02   6      1   0   1    0  0.000   1.0     0승0무1패       1패
# 1   2022-04-03   4      2   1   1    0  0.500   1.0     1승0무1패       1승
# 2   2022-04-05   6      3   1   2    0  0.333   2.0     1승0무2패       1패
# 3   2022-04-06   7      4   1   3    0  0.250   3.0     1승0무3패       2패
# 4   2022-04-07   7      5   1   4    0  0.200   4.0     1승0무4패       3패
# ..         ...  ..    ...  ..  ..  ...    ...   ...        ...      ...
# 166 2024-05-19   7     45  19  26    0  0.422  10.0     4승0무6패       1승
# 167 2024-05-21   8     46  19  27    0  0.413  10.0     4승0무6패       1패
# 168 2024-05-22   8     47  19  28    0  0.404  10.0     4승0무6패       2패
# 169 2024-05-23   8     48  20  28    0  0.417   9.0     5승0무5패       1승
# 170 2024-05-31   9     54  22  32    0  0.407  11.5     4승0무6패       2패
#
#      홈 경기 전적 원정 경기 전적 요일  원정팀   관중 수   시작시간   종료시간  경기시간
# 0      0-0-1    0-0-0  토   롯데   8257  14:00  17:12  3:12
# 1      1-0-1    0-0-0  일   롯데   6115  14:00  17:55  3:55
# 2      1-0-2    0-0-0  화   LG   2298  18:30  21:34  3:04
# 3      1-0-3    0-0-0  수   LG   2304  18:30  22:13  3:43
# 4      1-0-4    0-0-0  목   LG   2055  18:30  21:01  2:31
# ..       ...      ... ..  ...    ...    ...    ...   ...
# 166  10-0-14   9-0-12  일  SSG  10049  14:01  17:13  3:12
# 167  10-0-15   9-0-12  화   NC   3940  18:31  21:53  3:22
# 168  10-0-16   9-0-12  수   NC   4337  18:31  21:54  3:23
# 169  11-0-16   9-0-12  목   NC   3897  18:30  21:14  2:44
# 170  11-0-17  11-0-15  금  SSG   5680  18:30  21:23  2:53
#
# [171 rows x 18 columns]

# %% [markdown]
# ----
# ## 2022~2023년 데이터와 2024년 데이터 분리
# ----

# %%
# 2022 ~ 2023년도 데이터
kiwoom_2022_2023 = \
    kiwoom_new[
        (kiwoom_new.날짜.dt.year == 2022) | 
        (kiwoom_new.날짜.dt.year == 2023)
        ]
kiwoom_2022_2023
# Out:
#             날짜  순위  총 경기수  승리  패배  무승부     승률   게임차 최근 10경기 전적 연속 승패 현황  \
# 0   2022-04-02   6      1   0   1    0  0.000   1.0     0승0무1패       1패
# 1   2022-04-03   4      2   1   1    0  0.500   1.0     1승0무1패       1승
# 2   2022-04-05   6      3   1   2    0  0.333   2.0     1승0무2패       1패
# 3   2022-04-06   7      4   1   3    0  0.250   3.0     1승0무3패       2패
# 4   2022-04-07   7      5   1   4    0  0.200   4.0     1승0무4패       3패
# ..         ...  ..    ...  ..  ..  ...    ...   ...        ...      ...
# 138 2023-09-21  10    134  53  78    3  0.405  27.0     2승0무8패       2승
# 139 2023-09-28  10    136  55  78    3  0.414  27.0     4승0무6패       4승
# 140 2023-09-29  10    137  55  79    3  0.410  27.0     4승0무6패       1패
# 141 2023-10-07  10    141  57  81    3  0.413  27.5     6승0무4패       2승
# 142 2023-10-10   9    142  58  81    3  0.417  27.0     7승0무3패       3승
#
#      홈 경기 전적 원정 경기 전적 요일  원정팀   관중 수   시작시간   종료시간  경기시간
# 0      0-0-1    0-0-0  토   롯데   8257  14:00  17:12  3:12
# 1      1-0-1    0-0-0  일   롯데   6115  14:00  17:55  3:55
# 2      1-0-2    0-0-0  화   LG   2298  18:30  21:34  3:04
# 3      1-0-3    0-0-0  수   LG   2304  18:30  22:13  3:43
# 4      1-0-4    0-0-0  목   LG   2055  18:30  21:01  2:31
# ..       ...      ... ..  ...    ...    ...    ...   ...
# 138  30-2-35  23-1-43  목   NC   5178  18:30  21:18  2:48
# 139  31-2-35  24-1-43  목  SSG   7082  17:00  19:59  2:59
# 140  31-2-36  24-1-43  금  KIA  14472  14:00  17:57  3:57
# 141  32-2-36  25-1-45  토   LG  13301  17:00  19:49  2:49
# 142  33-2-36  25-1-45  화   삼성  11757  18:30  21:46  3:16
#
# [143 rows x 18 columns]

# %%
# 2024년도 데이터
kiwoom_2024 = \
    kiwoom_new[
        (kiwoom_new.날짜.dt.year == 2024)
        ].reset_index(drop=True)
kiwoom_2024
# Out:
#            날짜  순위  총 경기수  승리  패배  무승부     승률   게임차 최근 10경기 전적 연속 승패 현황  \
# 0  2024-03-29  10      4   0   4    0  0.000   4.0     0승0무4패       4패
# 1  2024-03-30   8      5   1   4    0  0.200   4.0     1승0무4패       1승
# 2  2024-03-31   7      6   2   4    0  0.333   4.0     2승0무4패       2승
# 3  2024-04-05   5      9   5   4    0  0.556   2.5     5승0무4패       5승
# 4  2024-04-06   5     10   6   4    0  0.600   1.5     6승0무4패       6승
# 5  2024-04-07   3     11   7   4    0  0.636   1.0     7승0무3패       7승
# 6  2024-04-12   3     15   9   6    0  0.600   2.5     8승0무2패       2승
# 7  2024-04-13   3     16  10   6    0  0.625   2.5     8승0무2패       3승
# 8  2024-04-14   3     17  11   6    0  0.647   2.5     8승0무2패       4승
# 9  2024-04-16   2     18  12   6    0  0.667   1.5     8승0무2패       5승
# 10 2024-04-17   3     19  12   7    0  0.632   2.5     7승0무3패       1패
# 11 2024-04-18   4     20  12   8    0  0.600   2.5     6승0무4패       2패
# 12 2024-04-23   5     24  13  11    0  0.542   4.5     5승0무5패       2패
# 13 2024-04-24   5     25  13  12    0  0.520   5.5     4승0무6패       3패
# 14 2024-04-25   6     26  13  13    0  0.500   6.5     3승0무7패       4패
# 15 2024-04-26   6     27  13  14    0  0.481   6.5     2승0무8패       5패
# 16 2024-04-27   6     28  13  15    0  0.464   6.5     1승0무9패       6패
# 17 2024-04-28   7     29  13  16    0  0.448   7.5     1승0무9패       7패
# 18 2024-05-07   7     35  15  20    0  0.429   8.0     2승0무8패       4패
# 19 2024-05-08   8     36  15  21    0  0.417   9.0     2승0무8패       5패
# 20 2024-05-09   8     37  15  22    0  0.405   9.0     2승0무8패       6패
# 21 2024-05-17   7     43  18  25    0  0.419   9.0     3승0무7패       1패
# 22 2024-05-18   7     44  18  26    0  0.409  10.0     3승0무7패       2패
# 23 2024-05-19   7     45  19  26    0  0.422  10.0     4승0무6패       1승
# 24 2024-05-21   8     46  19  27    0  0.413  10.0     4승0무6패       1패
# 25 2024-05-22   8     47  19  28    0  0.404  10.0     4승0무6패       2패
# 26 2024-05-23   8     48  20  28    0  0.417   9.0     5승0무5패       1승
# 27 2024-05-31   9     54  22  32    0  0.407  11.5     4승0무6패       2패
#
#     홈 경기 전적 원정 경기 전적 요일  원정팀   관중 수   시작시간   종료시간  경기시간
# 0     0-0-1    0-0-3  금   LG   8465  18:30  21:13  2:43
# 1     1-0-1    0-0-3  토   LG  13462  17:01  19:45  2:44
# 2     2-0-1    0-0-3  일   LG  11822  14:00  16:49  2:49
# 3     3-0-1    2-0-3  금   한화  16000  18:30  21:31  3:01
# 4     4-0-1    2-0-3  토   한화  16000  17:01  19:56  2:55
# 5     5-0-1    2-0-3  일   한화  16000  14:00  17:25  3:25
# 6     6-0-1    3-0-5  금   롯데   8838  18:30  21:31  3:01
# 7     7-0-1    3-0-5  토   롯데  14197  17:00  19:52  2:52
# 8     8-0-1    3-0-5  일   롯데  12333  14:00  17:45  3:45
# 9     9-0-1    3-0-5  화   KT   2877  18:31  21:04  2:33
# 10    9-0-2    3-0-5  수   KT   3272  18:31  22:07  3:36
# 11    9-0-3    3-0-5  목   KT   2901  18:30  21:01  2:31
# 12    9-0-4    4-0-7  화  KIA  10205  18:31  22:15  3:44
# 13    9-0-5    4-0-7  수  KIA  11048  18:30  21:29  2:59
# 14    9-0-6    4-0-7  목  KIA  13287  18:30  21:10  2:40
# 15    9-0-7    4-0-7  금   삼성   9519  18:30  21:19  2:49
# 16    9-0-8    4-0-7  토   삼성  15073  17:01  20:24  3:23
# 17    9-0-9    4-0-7  일   삼성  13354  14:01  17:39  3:38
# 18   9-0-10   6-0-10  화   두산   7339  18:30  21:16  2:46
# 19   9-0-11   6-0-10  수   두산   6405  18:30  21:19  2:49
# 20   9-0-12   6-0-10  목   두산   8658  18:31  21:23  2:52
# 21   9-0-13   9-0-12  금  SSG   9806  18:30  22:27  3:57
# 22   9-0-14   9-0-12  토  SSG  12133  17:01  19:53  2:52
# 23  10-0-14   9-0-12  일  SSG  10049  14:01  17:13  3:12
# 24  10-0-15   9-0-12  화   NC   3940  18:31  21:53  3:22
# 25  10-0-16   9-0-12  수   NC   4337  18:31  21:54  3:23
# 26  11-0-16   9-0-12  목   NC   3897  18:30  21:14  2:44
# 27  11-0-17  11-0-15  금  SSG   5680  18:30  21:23  2:53

# %% [markdown]
# ----
# ## 컬럼별 타겟 분석 시작
# ----

# %%
# # 데이터 검정 함수(ANOVA 검정)
# def ANOVATestData(func):

#     # 요일 순서 설정
#     orders = func.iloc[:,0].unique()

#     # 요일 순서에 맞게 정렬
#     func.iloc[:,0] = pd.Categorical(func.iloc[:,0], categories=orders, ordered=True)

#     # 요일별로 관중 수 그룹화
#     groups = [func.iloc[:,1][func.iloc[:,0] == order].values for order in orders]

#     # ANOVA 수행
#     f_stat, p_value = f_oneway(*groups)

#     if p_value < 0.05:
#         print(f"{func.columns[0]}별 {func.columns[1]} 차이가 유의미합니다.")
#     else:
#         print(f"{func.columns[0]}별 {func.columns[1]} 차이가 유의미하지 않습니다.")

#     return print(f"ANOVA 결과: F-통계량 = {f_stat:.2f}, p-값 = {p_value:.4f}")

# %%
# 컬럼별 관중 수 시각화
def columnBoxplot(func):
    # 관중 수 분포 확인
    fontKorea()

    # 상자 그림 그리기
    plt.figure(figsize=(12, 6))
    sns.boxplot(x=func.iloc[:,0], y=func.iloc[:,1], data=func)
    plt.title(f'{func.columns[0]}별 {func.columns[1]} 분포')
    plt.show()

# %%
# 컬럼별 관중 수 평균 막대그래프 시각화
def meanBarPlot(func):
    # 데이터 불러오기
    data = func.groupby(func.columns[0])[func.columns[1]].mean().sort_values().round(0).astype(int)

    # 막대 그래프 생성
    plt.figure(figsize=(10, 6))
    plt.bar(data.index, data.values, color='skyblue')
    plt.xlabel(func.columns[0])
    plt.ylabel("평균 관중 수")
    plt.ylim(3000,10000)
    plt.title(f"KBO 리그 {func.columns[0]}별 평균 관중 수(2022~2023년)")

    # 막대 그래프 위에 데이터 값 표시 (plt.bar_label 사용)
    plt.bar_label(plt.bar(data.index, data.values, color='skyblue'), data.values)
    

    # 그래프 표시
    plt.show()

# %%
# # 변환
# mapping = {data.index[i]: data[i+1] for i in range(len(data))}
# mapping
# # 변환 적용
# kiwoom_2022_2023[func.columns[0]].replace(mapping, inplace=True)
# kiwoom_2024[func.columns[0]].replace(mapping, inplace=True)

# %% [markdown]
# ----
# ### 순위별
# ----

# %%
# 순위 데이터만 가져오기
rank_crowd = kiwoom_2022_2023[['순위','관중 수']]
rank_crowd
# Out:
#      순위   관중 수
# 0     6   8257
# 1     4   6115
# 2     6   2298
# 3     7   2304
# 4     7   2055
# ..   ..    ...
# 138  10   5178
# 139  10   7082
# 140  10  14472
# 141  10  13301
# 142   9  11757
#
# [143 rows x 2 columns]

# %%
# 순위별 관중 수 분포 boxplot으로 시각화
columnBoxplot(rank_crowd)

# %%
# 순위별 평균 관중 수 boxplot으로 시각화
# 데이터 불러오기
data = rank_crowd.groupby(rank_crowd.columns[0])[rank_crowd.columns[1]].mean().round(0).astype(int)

# 막대 그래프 생성
plt.figure(figsize=(10, 6))
plt.bar(data.index, data.values, color='skyblue')
plt.xlabel(rank_crowd.columns[0])
plt.ylabel("평균 관중 수")
plt.ylim(3000,10000)
plt.title(f"KBO 리그 {rank_crowd.columns[0]}별 평균 관중 수(2022~2023년)")

# 막대 그래프 위에 데이터 값 표시 (plt.bar_label 사용)
plt.bar_label(plt.bar(data.index, data.values, color='skyblue'), data.values)


# 그래프 표시
plt.show()

# %%
# 변환
rank_mapping = {
    data.index[0] : 1,
    data.index[1] : 2,
    data.index[2] : 3,
    data.index[3] : 4,
    data.index[4] : 5,
    data.index[5] : 6,
    data.index[6] : 7,
    data.index[7] : 8,
    data.index[8] : 9,
    data.index[9] : 10
}
# 변환 적용
kiwoom_2022_2023['순위'].replace(rank_mapping, inplace=True)
kiwoom_2024['순위'].replace(rank_mapping, inplace=True)

# %% [markdown]
# ----
# ### 요일별
# ----

# %%
# 요일 데이터만 가져오기
date_crowd = kiwoom_2022_2023[['요일','관중 수']]
date_crowd
# Out:
#     요일   관중 수
# 0    토   8257
# 1    일   6115
# 2    화   2298
# 3    수   2304
# 4    목   2055
# ..  ..    ...
# 138  목   5178
# 139  목   7082
# 140  금  14472
# 141  토  13301
# 142  화  11757
#
# [143 rows x 2 columns]

# %%
# 순위별 관중 수 분포 boxplot으로 시각화
columnBoxplot(date_crowd)

# %%
# 순위별 평균 관중 수 boxplot으로 시각화
# 데이터 불러오기
data = date_crowd.groupby(date_crowd.columns[0])[date_crowd.columns[1]].mean().round(0).astype(int)

# 막대 그래프 생성
plt.figure(figsize=(10, 6))
plt.bar(data.index, data.values, color='skyblue')
plt.xlabel(date_crowd.columns[0])
plt.ylabel("평균 관중 수")
plt.ylim(3000,10000)
plt.title(f"KBO 리그 {date_crowd.columns[0]}별 평균 관중 수(2022~2023년)")

# 막대 그래프 위에 데이터 값 표시 (plt.bar_label 사용)
plt.bar_label(plt.bar(data.index, data.values, color='skyblue'), data.values)


# 그래프 표시
plt.show()

# %%
# 변환
day_mapping = {
    data.index[0] : 1,
    data.index[1] : 2,
    data.index[2] : 3,
    data.index[3] : 4,
    data.index[4] : 5,
    data.index[5] : 6
}
# 변환 적용
kiwoom_2022_2023['요일'].replace(day_mapping, inplace=True)
kiwoom_2024['요일'].replace(day_mapping, inplace=True)

# %%
kiwoom_2022_2023[['관중 수','순위','요일']]
# Out:
#       관중 수  순위  요일
# 0     8257   6   5
# 1     6115   4   4
# 2     2298   6   6
# 3     2304   7   3
# 4     2055   7   2
# ..     ...  ..  ..
# 138   5178  10   2
# 139   7082  10   2
# 140  14472  10   1
# 141  13301  10   5
# 142  11757   9   6
#
# [143 rows x 3 columns]

# %%
kiwoom_2022_2023[['관중 수','순위','요일']].corr()
# Out:
#           관중 수        순위        요일
# 관중 수  1.000000  0.376979  0.180620
# 순위    0.376979  1.000000 -0.029254
# 요일    0.180620 -0.029254  1.000000

# %%
kiwoom_rank_crowd = kiwoom_new[['순위','관중 수']]
kiwoom_rank_crowd

# %%
# 요일 순서 설정 (월, 화, 수, 목, 금, 토, 일)
rank_order = kiwoom_rank_crowd['순위'].unique()

# 요일 순서에 맞게 정렬
kiwoom_rank_crowd['요일'] = pd.Categorical(kiwoom_rank_crowd['순위'], categories=rank_order, ordered=True)

# %%
fontKorea()

# 상자 그림 그리기
plt.figure(figsize=(12, 6))
sns.boxplot(x='순위', y='관중 수', data=kiwoom_rank_crowd)
plt.title('순위별 관중 수 분포')
plt.show()

# %%
from scipy.stats import f_oneway

# 요일별로 관중 수 그룹화
groups = [kiwoom_rank_crowd['관중 수'][kiwoom_rank_crowd['순위'] == rank].values for rank in rank_order]

# ANOVA 수행
f_stat, p_value = f_oneway(*groups)

print(f"ANOVA 결과: F-통계량 = {f_stat:.2f}, p-값 = {p_value:.4f}")

# %%
if p_value < 0.05:
    print("순위별 관중 수 차이가 유의미합니다.")
else:
    print("순위별 관중 수 차이가 유의미하지 않습니다.")

# %%
# 필요한 열만 선택
kiwoom_date_crowd = kiwoom_new[['요일', '관중 수']]
kiwoom_date_crowd

# %%
kiwoom_date_crowd['요일'].unique()

# %%
# 요일 순서 설정 (월, 화, 수, 목, 금, 토, 일)
day_order = kiwoom_date_crowd['요일'].unique()

# 요일 순서에 맞게 정렬
kiwoom_date_crowd['요일'] = pd.Categorical(kiwoom_date_crowd['요일'], categories=day_order, ordered=True)

# %%
fontKorea()

# 상자 그림 그리기
plt.figure(figsize=(12, 6))
sns.boxplot(x='요일', y='관중 수', data=kiwoom_date_crowd)
plt.title('요일별 관중 수 분포')
plt.show()

# %%
from scipy.stats import f_oneway

# 요일별로 관중 수 그룹화
groups = [kiwoom_date_crowd['관중 수'][kiwoom_date_crowd['요일'] == day].values for day in day_order]

# ANOVA 수행
f_stat, p_value = f_oneway(*groups)

print(f"ANOVA 결과: F-통계량 = {f_stat:.2f}, p-값 = {p_value:.4f}")

# %%
if p_value < 0.05:
    print("요일별 관중 수 차이가 유의미합니다.")
else:
    print("요일별 관중 수 차이가 유의미하지 않습니다.")

# %%
# 필요한 열만 선택
kiwoom_start_time_crowd = kiwoom_new[['시작시간', '관중 수']]
kiwoom_start_time_crowd

# %%
kiwoom_start_time_crowd.시작시간.unique()

# %%
kiwoom_start_time_crowd[
        (kiwoom_start_time_crowd['시작시간'] == '18:29') |
        (kiwoom_start_time_crowd['시작시간'] == '18:33') |
        (kiwoom_start_time_crowd['시작시간'] == '18:31') 
        ]

# %%
target_rows_18_30 = \
    kiwoom_start_time_crowd[
        (kiwoom_start_time_crowd['시작시간'] == '18:29') |
        (kiwoom_start_time_crowd['시작시간'] == '18:33') |
        (kiwoom_start_time_crowd['시작시간'] == '18:31') 
        ]

# 시작시간 변경
kiwoom_start_time_crowd.loc[target_rows_18_30.index, '시작시간'] = '18:30'

# %%
target_rows_14_00 = \
    kiwoom_start_time_crowd[
        (kiwoom_start_time_crowd['시작시간'] == '13:59') |
        (kiwoom_start_time_crowd['시작시간'] == '14:01')
        ]

# 시작시간 변경
kiwoom_start_time_crowd.loc[target_rows_14_00.index, '시작시간'] = '14:00'

# %%
target_rows_17_00 = \
    kiwoom_start_time_crowd[
        (kiwoom_start_time_crowd['시작시간'] == '17:01') |
        (kiwoom_start_time_crowd['시작시간'] == '18:00') |
        (kiwoom_start_time_crowd['시작시간'] == '18:01') 
        ]

# 시작시간 변경
kiwoom_start_time_crowd.loc[target_rows_17_00.index, '시작시간'] = '17:00'

# %%
kiwoom_start_time_crowd.시작시간.unique()

# %%
# 시작시간 순서 설정
start_order = kiwoom_start_time_crowd['시작시간'].unique()

# 요일 순서에 맞게 정렬
kiwoom_start_time_crowd['시작시간'] = pd.Categorical(kiwoom_start_time_crowd['시작시간'], categories=start_order, ordered=True)

# %%
fontKorea()

# 상자 그림 그리기
plt.figure(figsize=(12, 6))
sns.boxplot(x='시작시간', y='관중 수', data=kiwoom_start_time_crowd)
plt.title('시작시간별 관중 수 분포')
plt.show()

# %%
from scipy.stats import f_oneway

# 시작시간으로 관중 수 그룹화
groups = [kiwoom_start_time_crowd['관중 수'][kiwoom_start_time_crowd['시작시간'] == start].values for start in start_order]

# ANOVA 수행
f_stat, p_value = f_oneway(*groups)

print(f"ANOVA 결과: F-통계량 = {f_stat:.2f}, p-값 = {p_value:.4f}")

# %%
if p_value < 0.05:
    print("시작시간별 관중 수 차이가 유의미합니다.")
else:
    print("시작시간별 관중 수 차이가 유의미하지 않습니다.")

# %%
# 필요한 열만 선택
kiwoom_away_crowd = kiwoom_new[['원정팀', '관중 수']]
kiwoom_away_crowd

# %%
kiwoom_away_crowd.원정팀.unique()

# %%
# 시작시간 순서 설정
away_order = \
    kiwoom_away_crowd['원정팀'].unique()

# 요일 순서에 맞게 정렬
kiwoom_away_crowd['원정팀'] = \
    pd.Categorical(
        kiwoom_away_crowd['원정팀'],
        categories=away_order, ordered=True
        )

# %%
fontKorea()

# 상자 그림 그리기
plt.figure(figsize=(12, 6))
sns.boxplot(
    x='원정팀', y='관중 수',
    data=kiwoom_away_crowd
    )
plt.title('원정팀별 관중 수 분포')
plt.show()

# %%
from scipy.stats import f_oneway

# 요일별로 관중 수 그룹화
groups = \
    [
        kiwoom_away_crowd['관중 수'][kiwoom_away_crowd['원정팀'] == away].values for away in away_order
    ]

# ANOVA 수행
f_stat, p_value = f_oneway(*groups)

print(f"ANOVA 결과: F-통계량 = {f_stat:.2f}, p-값 = {p_value:.4f}")

# %%
if p_value < 0.05:
    print("원정팀별 관중 수 차이가 유의미합니다.")
else:
    print("원정팀별 관중 수 차이가 유의미하지 않습니다.")

# %%
kiwoom_new

# %%
kiwoom_final = kiwoom_new[['관중 수','요일','원정팀','시작시간','날짜','순위','연속 승패 현황']]
kiwoom_final

# %%
target_rows_18_30 = \
    kiwoom_final[
        (kiwoom_final['시작시간'] == '18:29') |
        (kiwoom_final['시작시간'] == '18:33') |
        (kiwoom_final['시작시간'] == '18:31') 
        ]

# 시작시간 변경
kiwoom_final.loc[target_rows_18_30.index, '시작시간'] = '18:30'

# %%
target_rows_14_00 = \
    kiwoom_final[
        (kiwoom_final['시작시간'] == '13:59') |
        (kiwoom_final['시작시간'] == '14:01')
        ]

# 시작시간 변경
kiwoom_final.loc[target_rows_14_00.index, '시작시간'] = '14:00'

# %%
target_rows_17_00 = \
    kiwoom_final[
        (kiwoom_final['시작시간'] == '17:01') |
        (kiwoom_final['시작시간'] == '18:00') |
        (kiwoom_final['시작시간'] == '18:01') 
        ]

# 시작시간 변경
kiwoom_final.loc[target_rows_17_00.index, '시작시간'] = '17:00'

# %%
kiwoom_final

# %%
kiwoom_final_2022_2023 = \
    kiwoom_final[
        (kiwoom_final.날짜.dt.year == 2022) | 
        (kiwoom_final.날짜.dt.year == 2023)
        ]
kiwoom_final_2022_2023

# %%
kiwoom_final_2024 = \
    kiwoom_final[
        (kiwoom_final.날짜.dt.year == 2024)
        ]
kiwoom_final_2024

# %%
kiwoom_final_2024 = kiwoom_final_2024.reset_index(drop=True)
kiwoom_final_2024

# %%
# 데이터 불러오기 (kiwoom_2022_2023 DataFrame)
data = kiwoom_final_2022_2023.groupby('요일')['관중 수'].mean().sort_values().round(0).astype(int)

# 막대 그래프 생성
plt.figure(figsize=(10, 6))
plt.bar(data.index, data.values, color='skyblue')  # 요일 이름 사용
plt.xlabel("요일")
plt.ylabel("평균 관중 수")
plt.ylim(3000,10000)
plt.title("KBO 리그 요일별 평균 관중 수(2022~2023년)")

# 막대 그래프 위에 데이터 값 표시 (plt.bar_label 사용)
plt.bar_label(plt.bar(data.index, data.values, color='skyblue'), data.values)

# 그래프 표시
plt.show()

# %%
# 변환
day_mapping = {
    '목': data[0],
    '수': data[1],
    '화': data[2],
    '금': data[3],
    '일': data[4],
    '토': data[5]
}
# 변환 적용
kiwoom_final_2022_2023['요일'].replace(day_mapping, inplace=True)
kiwoom_final_2024['요일'].replace(day_mapping, inplace=True)

# %%
kiwoom_final_2022_2023[['관중 수','요일']].corr()

# %%
# 데이터 불러오기 (kiwoom_2022_2023 DataFrame)
data = kiwoom_final_2022_2023.groupby('시작시간')['관중 수'].mean().sort_values().round(0).astype(int)

# 막대 그래프 생성
plt.figure(figsize=(10, 6))
plt.bar(data.index, data.values, color='skyblue')  # 요일 이름 사용
plt.xlabel("시작시간팀")
plt.ylabel("평균 관중 수")
plt.ylim(3000,10000)
plt.title("KBO 리그 시작시간별 평균 관중 수(2022~2023년)")

# 막대 그래프 위에 데이터 값 표시 (plt.bar_label 사용)
plt.bar_label(plt.bar(data.index, data.values, color='skyblue'), data.values)

# 그래프 표시
plt.show()

# %%
# 변환
day_mapping = {
    '18:30': data[0],
    '17:00': data[1],
    '14:00': data[2]
}
# 변환 적용
kiwoom_final_2022_2023['시작시간'].replace(day_mapping, inplace=True)
kiwoom_final_2024['시작시간'].replace(day_mapping, inplace=True)

# %%
kiwoom_final_2022_2023[['관중 수','요일','시작시간']].corr()

# %%
# 데이터 불러오기 (kiwoom_2022_2023 DataFrame)
data = kiwoom_final_2022_2023.groupby('원정팀')['관중 수'].mean().sort_values().round(0).astype(int)

# 막대 그래프 생성
plt.figure(figsize=(10, 6))
plt.bar(data.index, data.values, color='skyblue')  # 요일 이름 사용
plt.xlabel("원정팀")
plt.ylabel("평균 관중 수")
plt.ylim(3000,10000)
plt.title("KBO 리그 시작시간별 평균 관중 수(2022~2023년)")

# 막대 그래프 위에 데이터 값 표시 (plt.bar_label 사용)
plt.bar_label(plt.bar(data.index, data.values, color='skyblue'), data.values)

# 그래프 표시
plt.show()

# %%
# 변환
day_mapping = {
    'KT': data[0],
    'NC': data[1],
    '두산': data[2],
    '삼성': data[3],
    'LG': data[4],
    'SSG': data[5],
    '한화': data[6],
    'KIA': data[7],
    '롯데': data[8]
}
# 변환 적용
kiwoom_final_2022_2023['원정팀'].replace(day_mapping, inplace=True)
kiwoom_final_2024['원정팀'].replace(day_mapping, inplace=True)

# %%
kiwoom_final_2022_2023[['관중 수','요일','시작시간','원정팀']].corr()

# %%
# 데이터 불러오기 (kiwoom_2022_2023 DataFrame)
data = kiwoom_final_2022_2023.groupby('순위')['관중 수'].mean().sort_values().round(0).astype(int)

# 막대 그래프 생성
plt.figure(figsize=(10, 6))
plt.bar(data.index, data.values, color='skyblue')  # 요일 이름 사용
plt.xlabel("순위")
plt.ylabel("평균 관중 수")
plt.ylim(3000,10000)
plt.title("KBO 리그 순위별 평균 관중 수(2022~2023년)")

# 막대 그래프 위에 데이터 값 표시 (plt.bar_label 사용)
plt.bar_label(plt.bar(data.index, data.values, color='skyblue'), data.values)

# 그래프 표시
plt.show()

# %%
data

# %%
# 변환
day_mapping = {
    7: data[1],
    2: data[2],
    6: data[3],
    3: data[4],
    4: data[5],
    5: data[6],
    9: data[7],
    1: data[8],
    10: data[9],
    8: data[10]
}
# 변환 적용
kiwoom_final_2022_2023['순위'].replace(day_mapping, inplace=True)
kiwoom_final_2024['순위'].replace(day_mapping, inplace=True)

# %%
kiwoom_final_2022_2023

# %%
kiwoom_final_2022_2023['연속 승패 현황'].unique()

# %%
# 데이터 불러오기 (kiwoom_2022_2023 DataFrame)
data = kiwoom_final_2022_2023.groupby('연속 승패 현황')['관중 수'].mean().sort_values().round(0).astype(int)

# 막대 그래프 생성
plt.figure(figsize=(10, 6))
plt.bar(data.index, data.values, color='skyblue')  # 요일 이름 사용
plt.xlabel("연속 승패 현황")
plt.ylabel("승패별 관중 수")
plt.ylim(3000,10000)
plt.title("KBO 승패별 평균 관중 수(2022~2023년)")

# 막대 그래프 위에 데이터 값 표시 (plt.bar_label 사용)
plt.bar_label(plt.bar(data.index, data.values, color='skyblue'), data.values)

# 그래프 표시
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
# k-mean로 관중 수 범위 나눌 k 값 찾기

# 데이터 전처리: 타깃 컬럼과 피쳐 컬럼 분리
features = kiwoom_2022_2023[['요일','순위']]
target = kiwoom_2022_2023[['관중 수']]

attendance_shape = np.array(target).reshape(-1,1)

# 특성 표준화
scaler = StandardScaler()
features_scaled = scaler.fit_transform(attendance_shape)

# 엘보우 방법을 사용하여 최적의 클러스터 수 찾기
sse = []
k_range = range(3, 15)  # 3부터 15까지의 k 값에 대해 확인

for k in k_range:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(attendance_shape)
    sse.append(kmeans.inertia_)

# 엘보우 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(k_range, sse, marker='o')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Sum of squared distances (SSE)')
plt.title('Elbow Method For Optimal k')
plt.grid(True)
plt.show()

# %%
# K-means 클러스터링
kmeans = KMeans(n_clusters=5)
clusters = kmeans.fit_predict(attendance_shape)
clusters

# 각 클러스터의 관중 수 범위 계산
cluster_ranges = {}

for cluster in range(5):
    cluster_data = \
        kiwoom_2022_2023[clusters == cluster]
    min_attendance = \
        cluster_data['관중 수'].min()
    max_attendance = \
        cluster_data['관중 수'].max()
    cluster_ranges[cluster] = (min_attendance, max_attendance)
cluster_ranges
# Out:
# {0: (3564, 5952),
#  1: (13301, 16000),
#  2: (774, 3238),
#  3: (9442, 12545),
#  4: (6064, 8817)}

# %%
np.mean(cluster_ranges[1]).round(0) 2
np.mean(cluster_ranges[4]).round(0) 5
np.mean(cluster_ranges[2]).round(0) 3
np.mean(cluster_ranges[0]).round(0) 1
np.mean(cluster_ranges[3]).round(0) 4

# %%
# 규칙에 따라 관중 수를 분류하여 새로운 컬럼에 할당
# kiwoom_2022_2023['관중수 분류'] = \
#     pd.cut(kiwoom_2022_2023['관중 수'], 
#     bins=[0, 3500, 6000, 9000, 13000, float('inf')], 
#     labels=[
#         np.mean(cluster_ranges[1]).round(0),
#         np.mean(cluster_ranges[4]).round(0),
#         np.mean(cluster_ranges[2]).round(0),
#         np.mean(cluster_ranges[0]).round(0),
#         np.mean(cluster_ranges[3]).round(0)
#         ], 
#     right=False)

# %%
# 규칙에 따라 관중 수를 분류하여 새로운 컬럼에 할당
kiwoom_2022_2023['관중수 분류'] = \
    pd.cut(kiwoom_2022_2023['관중 수'], 
    bins=[0, 3300, 6000, 9100, 12900, float('inf')], 
    labels=[
        2,
        5,
        3,
        1,
        4
        ], 
    right=False)

# %%
kiwoom_2022_2023['관중수 분류'] = kiwoom_2022_2023['관중수 분류'].astype(int)
kiwoom_2022_2023
# Out:
#             날짜  순위  총 경기수  승리  패배  무승부     승률   게임차 최근 10경기 전적 연속 승패 현황  \
# 0   2022-04-02   6      1   0   1    0  0.000   1.0     0승0무1패       1패
# 1   2022-04-03   4      2   1   1    0  0.500   1.0     1승0무1패       1승
# 2   2022-04-05   6      3   1   2    0  0.333   2.0     1승0무2패       1패
# 3   2022-04-06   7      4   1   3    0  0.250   3.0     1승0무3패       2패
# 4   2022-04-07   7      5   1   4    0  0.200   4.0     1승0무4패       3패
# ..         ...  ..    ...  ..  ..  ...    ...   ...        ...      ...
# 138 2023-09-21  10    134  53  78    3  0.405  27.0     2승0무8패       2승
# 139 2023-09-28  10    136  55  78    3  0.414  27.0     4승0무6패       4승
# 140 2023-09-29  10    137  55  79    3  0.410  27.0     4승0무6패       1패
# 141 2023-10-07  10    141  57  81    3  0.413  27.5     6승0무4패       2승
# 142 2023-10-10   9    142  58  81    3  0.417  27.0     7승0무3패       3승
#
#      홈 경기 전적 원정 경기 전적  요일  원정팀   관중 수   시작시간   종료시간  경기시간  관중수 분류
# 0      0-0-1    0-0-0   5   롯데   8257  14:00  17:12  3:12       3
# 1      1-0-1    0-0-0   4   롯데   6115  14:00  17:55  3:55       3
# 2      1-0-2    0-0-0   6   LG   2298  18:30  21:34  3:04       2
# 3      1-0-3    0-0-0   3   LG   2304  18:30  22:13  3:43       2
# 4      1-0-4    0-0-0   2   LG   2055  18:30  21:01  2:31       2
# ..       ...      ...  ..  ...    ...    ...    ...   ...     ...
# 138  30-2-35  23-1-43   2   NC   5178  18:30  21:18  2:48       5
# 139  31-2-35  24-1-43   2  SSG   7082  17:00  19:59  2:59       3
# 140  31-2-36  24-1-43   1  KIA  14472  14:00  17:57  3:57       4
# 141  32-2-36  25-1-45   5   LG  13301  17:00  19:49  2:49       4
# 142  33-2-36  25-1-45   6   삼성  11757  18:30  21:46  3:16       1
#
# [143 rows x 19 columns]

# %%
# 규칙에 따라 관중 수를 분류하여 새로운 컬럼에 할당
kiwoom_2024['관중수 분류'] = \
    pd.cut(kiwoom_2024['관중 수'], 
    bins=[0, 3300, 6000, 9100, 12900, float('inf')], 
    labels=[
        2,
        5,
        3,
        1,
        4
        ], 
    right=False)

# %%
kiwoom_2024['관중수 분류'] = kiwoom_2024['관중수 분류'].astype(int)
kiwoom_2024
# Out:
#            날짜  순위  총 경기수  승리  패배  무승부     승률   게임차 최근 10경기 전적 연속 승패 현황  \
# 0  2024-03-29  10      4   0   4    0  0.000   4.0     0승0무4패       4패
# 1  2024-03-30   8      5   1   4    0  0.200   4.0     1승0무4패       1승
# 2  2024-03-31   7      6   2   4    0  0.333   4.0     2승0무4패       2승
# 3  2024-04-05   5      9   5   4    0  0.556   2.5     5승0무4패       5승
# 4  2024-04-06   5     10   6   4    0  0.600   1.5     6승0무4패       6승
# 5  2024-04-07   3     11   7   4    0  0.636   1.0     7승0무3패       7승
# 6  2024-04-12   3     15   9   6    0  0.600   2.5     8승0무2패       2승
# 7  2024-04-13   3     16  10   6    0  0.625   2.5     8승0무2패       3승
# 8  2024-04-14   3     17  11   6    0  0.647   2.5     8승0무2패       4승
# 9  2024-04-16   2     18  12   6    0  0.667   1.5     8승0무2패       5승
# 10 2024-04-17   3     19  12   7    0  0.632   2.5     7승0무3패       1패
# 11 2024-04-18   4     20  12   8    0  0.600   2.5     6승0무4패       2패
# 12 2024-04-23   5     24  13  11    0  0.542   4.5     5승0무5패       2패
# 13 2024-04-24   5     25  13  12    0  0.520   5.5     4승0무6패       3패
# 14 2024-04-25   6     26  13  13    0  0.500   6.5     3승0무7패       4패
# 15 2024-04-26   6     27  13  14    0  0.481   6.5     2승0무8패       5패
# 16 2024-04-27   6     28  13  15    0  0.464   6.5     1승0무9패       6패
# 17 2024-04-28   7     29  13  16    0  0.448   7.5     1승0무9패       7패
# 18 2024-05-07   7     35  15  20    0  0.429   8.0     2승0무8패       4패
# 19 2024-05-08   8     36  15  21    0  0.417   9.0     2승0무8패       5패
# 20 2024-05-09   8     37  15  22    0  0.405   9.0     2승0무8패       6패
# 21 2024-05-17   7     43  18  25    0  0.419   9.0     3승0무7패       1패
# 22 2024-05-18   7     44  18  26    0  0.409  10.0     3승0무7패       2패
# 23 2024-05-19   7     45  19  26    0  0.422  10.0     4승0무6패       1승
# 24 2024-05-21   8     46  19  27    0  0.413  10.0     4승0무6패       1패
# 25 2024-05-22   8     47  19  28    0  0.404  10.0     4승0무6패       2패
# 26 2024-05-23   8     48  20  28    0  0.417   9.0     5승0무5패       1승
# 27 2024-05-31   9     54  22  32    0  0.407  11.5     4승0무6패       2패
#
#     홈 경기 전적 원정 경기 전적  요일  원정팀   관중 수   시작시간   종료시간  경기시간  관중수 분류
# 0     0-0-1    0-0-3   1   LG   8465  18:30  21:13  2:43       3
# 1     1-0-1    0-0-3   5   LG  13462  17:01  19:45  2:44       4
# 2     2-0-1    0-0-3   4   LG  11822  14:00  16:49  2:49       1
# 3     3-0-1    2-0-3   1   한화  16000  18:30  21:31  3:01       4
# 4     4-0-1    2-0-3   5   한화  16000  17:01  19:56  2:55       4
# 5     5-0-1    2-0-3   4   한화  16000  14:00  17:25  3:25       4
# 6     6-0-1    3-0-5   1   롯데   8838  18:30  21:31  3:01       3
# 7     7-0-1    3-0-5   5   롯데  14197  17:00  19:52  2:52       4
# 8     8-0-1    3-0-5   4   롯데  12333  14:00  17:45  3:45       1
# 9     9-0-1    3-0-5   6   KT   2877  18:31  21:04  2:33       2
# 10    9-0-2    3-0-5   3   KT   3272  18:31  22:07  3:36       2
# 11    9-0-3    3-0-5   2   KT   2901  18:30  21:01  2:31       2
# 12    9-0-4    4-0-7   6  KIA  10205  18:31  22:15  3:44       1
# 13    9-0-5    4-0-7   3  KIA  11048  18:30  21:29  2:59       1
# 14    9-0-6    4-0-7   2  KIA  13287  18:30  21:10  2:40       4
# 15    9-0-7    4-0-7   1   삼성   9519  18:30  21:19  2:49       1
# 16    9-0-8    4-0-7   5   삼성  15073  17:01  20:24  3:23       4
# 17    9-0-9    4-0-7   4   삼성  13354  14:01  17:39  3:38       4
# 18   9-0-10   6-0-10   6   두산   7339  18:30  21:16  2:46       3
# 19   9-0-11   6-0-10   3   두산   6405  18:30  21:19  2:49       3
# 20   9-0-12   6-0-10   2   두산   8658  18:31  21:23  2:52       3
# 21   9-0-13   9-0-12   1  SSG   9806  18:30  22:27  3:57       1
# 22   9-0-14   9-0-12   5  SSG  12133  17:01  19:53  2:52       1
# 23  10-0-14   9-0-12   4  SSG  10049  14:01  17:13  3:12       1
# 24  10-0-15   9-0-12   6   NC   3940  18:31  21:53  3:22       5
# 25  10-0-16   9-0-12   3   NC   4337  18:31  21:54  3:23       5
# 26  11-0-16   9-0-12   2   NC   3897  18:30  21:14  2:44       5
# 27  11-0-17  11-0-15   1  SSG   5680  18:30  21:23  2:53       5

# %%
kiwoom_2022_2023[['순위','요일','관중수 분류']]
# Out:
#      순위  요일  관중수 분류
# 0     6   5       3
# 1     4   4       3
# 2     6   6       2
# 3     7   3       2
# 4     7   2       2
# ..   ..  ..     ...
# 138  10   2       5
# 139  10   2       3
# 140  10   1       4
# 141  10   5       4
# 142   9   6       1
#
# [143 rows x 3 columns]

# %%
kiwoom_2022_2023[['관중수 분류','순위','요일']].corr()
# Out:
#           관중수 분류        순위        요일
# 관중수 분류  1.000000 -0.112227 -0.032910
# 순위     -0.112227  1.000000 -0.029254
# 요일     -0.032910 -0.029254  1.000000

# %%
kiwoom_2022_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 143 entries, 0 to 142
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   날짜          143 non-null    datetime64[ns]
#  1   순위          143 non-null    int64
#  2   총 경기수       143 non-null    int64
#  3   승리          143 non-null    int64
#  4   패배          143 non-null    int64
#  5   무승부         143 non-null    int64
#  6   승률          143 non-null    float64
#  7   게임차         143 non-null    float64
#  8   최근 10경기 전적  143 non-null    object
#  9   연속 승패 현황    143 non-null    object
#  10  홈 경기 전적     143 non-null    object
#  11  원정 경기 전적    143 non-null    object
#  12  요일          143 non-null    int64
#  13  원정팀         143 non-null    object
#  14  관중 수        143 non-null    int64
#  15  시작시간        143 non-null    object
#  16  종료시간        143 non-null    object
#  17  경기시간        143 non-null    object
#  18  관중수 분류      143 non-null    int64
# dtypes: datetime64[ns](1), float64(2), int64(8), object(8)
# memory usage: 22.3+ KB

# %%
kiwoom_2024[['순위','요일','관중수 분류']]
# Out:
#     순위  요일  관중수 분류
# 0   10   1       3
# 1    8   5       4
# 2    7   4       1
# 3    5   1       4
# 4    5   5       4
# 5    3   4       4
# 6    3   1       3
# 7    3   5       4
# 8    3   4       1
# 9    2   6       2
# 10   3   3       2
# 11   4   2       2
# 12   5   6       1
# 13   5   3       1
# 14   6   2       4
# 15   6   1       1
# 16   6   5       4
# 17   7   4       4
# 18   7   6       3
# 19   8   3       3
# 20   8   2       3
# 21   7   1       1
# 22   7   5       1
# 23   7   4       1
# 24   8   6       5
# 25   8   3       5
# 26   8   2       5
# 27   9   1       5

# %%
kiwoom_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   날짜          28 non-null     datetime64[ns]
#  1   순위          28 non-null     int64
#  2   총 경기수       28 non-null     int64
#  3   승리          28 non-null     int64
#  4   패배          28 non-null     int64
#  5   무승부         28 non-null     int64
#  6   승률          28 non-null     float64
#  7   게임차         28 non-null     float64
#  8   최근 10경기 전적  28 non-null     object
#  9   연속 승패 현황    28 non-null     object
#  10  홈 경기 전적     28 non-null     object
#  11  원정 경기 전적    28 non-null     object
#  12  요일          28 non-null     int64
#  13  원정팀         28 non-null     object
#  14  관중 수        28 non-null     int64
#  15  시작시간        28 non-null     object
#  16  종료시간        28 non-null     object
#  17  경기시간        28 non-null     object
#  18  관중수 분류      28 non-null     int64
# dtypes: datetime64[ns](1), float64(2), int64(8), object(8)
# memory usage: 4.3+ KB

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
# 데이터 준비 (x는 피쳐, y는 타겟)
x = kiwoom_2022_2023[['요일']]
y = kiwoom_2022_2023['관중수 분류']

# 실제 데이터 준비
test_x = kiwoom_2024[['요일']]
test_y = kiwoom_2024['관중수 분류']

# %%
def cross_validation(classifier, features, labels):
    cv_scores = []
    for i in range(10):
        scores = cross_val_score(
            classifier, # 함수
            features,
            labels,
            cv=10,
            scoring='accuracy',
            n_jobs=-1
        )
        cv_scores.append(round(scores.mean()*100,0))
    return cv_scores

# %%
# 랜덤포레스트
cross_validation(RandomForestClassifier(), x, y)
# Out:
# [27.0, 28.0, 26.0, 28.0, 31.0, 26.0, 28.0, 27.0, 29.0, 27.0]

# %%
# 데이터 학습 시키고 예측하기
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(x, y)
pre = clf.predict(test_x)

# 정답률 구하기
# np.mean(pre == test_label)
from sklearn import metrics
ac_score = metrics.accuracy_score(test_y, pre)
cl_report = metrics.classification_report(test_y, pre)

print('정답률 =', ac_score)
print('리포트 =', cl_report)
# Out:
# 정답률 = 0.2857142857142857
# 리포트 =               precision    recall  f1-score   support
#
#            1       0.50      0.25      0.33         8
#            2       0.50      0.33      0.40         3
#            3       0.11      0.20      0.14         5
#            4       0.00      0.00      0.00         8
#            5       0.31      1.00      0.47         4
#
#     accuracy                           0.29        28
#    macro avg       0.28      0.36      0.27        28
# weighted avg       0.26      0.29      0.23        28

# %%
# 랜덤포레스트
cross_validation(SVC(), x, y)

# %%
# SVC 모델 생성
model = RandomForestClassifier()

# 10-겹 교차 검증으로 정확도 평가
scores = cross_val_score(model, x, y, cv=10, scoring='accuracy')

# 평균 정확도 출력
print("평균 정확도:", round(scores.mean()*100),'%')
# 각 교차 검증 점수 출력
print("각 교차 검증 점수:", scores.round(2)*100)

# %%
# 의사결정 나무
cross_validation(tree.DecisionTreeClassifier(), x, y)

# %%
# 손글씨
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2)

# %%
# 의사결정 나무
dtree = tree.DecisionTreeClassifier()
dtree = dtree.fit(x, y)
print(f"dTree : {dtree.score(X_test, Y_test)*100}")

# KNN
knn = KNeighborsClassifier().fit(X_train, Y_train)
print(f"kNN : {knn.score(X_test, Y_test)*100}")

# SVM
svm = SVC(probability=True).fit(X_train, Y_train)
print(f"svm : {svm.score(X_test, Y_test)*100}")
# Out:
# dTree : 58.620689655172406
# kNN : 27.586206896551722
# svm : 31.03448275862069

# %%
from sklearn.ensemble import VotingClassifier
voting_clf = VotingClassifier(
    estimators=[
        ('decision_tree', dtree),
        ('knn', knn),
        ('svm', svm),
    ],
    weights=[1,1,1],
    voting='hard'
).fit(X_train, Y_train)

voting_clf.score(X_test, Y_test)*100
# Out:
# 27.586206896551722

# %%
voting_clf = VotingClassifier(
    estimators=[
        ('decision_tree', dtree),
        ('knn', knn),
        ('svm', svm),
    ],
    weights=[1,1,1],
    voting='soft'
).fit(X_train, Y_train)

voting_clf.score(X_test, Y_test)*100
# Out:
# 27.586206896551722
