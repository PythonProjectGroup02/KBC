# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

import time

# -----
game_result = []
# -----

# Chrome Browser와 Chrome Driver Version 확인
chrome_options = webdriver.ChromeOptions()

# 요청
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
url = 'https://www.koreabaseball.com/Schedule/Schedule.aspx'
driver.get(url)

time.sleep(2)

# 키움 탭 선택
driver.find_element(By.XPATH, '//*[@id="boxList"]/ul/li[6]/a').click()

# 연도 선택 박스
year_box = driver.find_element(By.CLASS_NAME, 'date').find_element(By.ID, 'ddlYear')
year_lists = year_box.text.split('\n')[:3]
year_lists.reverse()

# 월별 선택 박스
month_box = driver.find_element(By.CLASS_NAME, 'date').find_element(By.ID, 'ddlMonth')
month_lists = month_box.text.split('\n')

# year_lists = ['2022','2023']
# month_lists = ['10','11','12']
# year_lists = ['2022','2023']
# month_lists = ['9','10']

# 날짜입력 (년/월)
for year in year_lists :
    year_box.send_keys(year)
    time.sleep(1)

    for month in month_lists :
        month_box.send_keys(month)
        time.sleep(1)

        try :
            # 데이터 한줄, tbody에서 tr 가져오기
            tr_lists = driver.find_element(By.XPATH, '//*[@id="tblScheduleList"]/tbody').find_elements(By.TAG_NAME, 'tr')
            
            print(len(tr_lists))

            # if tr_lists[0].text == '데이터가 없습니다.' :
            #     print('-- 데이터가 없습니다 --')
            #     continue

            game_dict = {}

            for tr in tr_lists :
                print(year, month)

                print('tr >>>>', tr.text)

                # 날짜에 해당하는 경기의 url
                try :
                    review_url = ''
                    review_url = tr.find_element(By.TAG_NAME, 'a').get_attribute('href')
                except :
                    print('url error, 다음 경기 -----')
                    continue

                game_driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
                game_driver.get(review_url)

                time.sleep(1.5)

                # 구장 위치
                stadium = game_driver.find_element(By.ID, 'txtStadium').text

                # 경기 날짜
                date = game_driver.find_element(By.ID, 'lblGameDate').text

                # 시작 시간
                start_time = game_driver.find_element(By.ID, 'txtStartTime').text[5:]

                # 종료 시간
                end_time = game_driver.find_element(By.ID, 'txtEndTime').text[5:]

                # 진행한 시간
                run_time = game_driver.find_element(By.ID, 'txtRunTime').text[7:]

                # away팀 투수 테이블
                away_pitcher = game_driver.find_element(By.ID, 'tblAwayPitcher').find_element(By.TAG_NAME, 'tbody').find_element(By.TAG_NAME, 'tr')
                away_pitcher_name = away_pitcher.find_elements(By.TAG_NAME, 'td')[0].text

                # home팀 투수 테이블
                home_pitcher = game_driver.find_element(By.ID, 'tblHomePitcher').find_element(By.TAG_NAME, 'tbody').find_element(By.TAG_NAME, 'tr')
                home_pitcher_name = home_pitcher.find_elements(By.TAG_NAME, 'td')[0].text

                # time.sleep(1) 

                # dict 구성
                game_dict = {
                    '날짜' : date,
                    '시작시간' : start_time,
                    '종료시간' : end_time,
                    '경기시간' : run_time,
                    '홈팀 선발' : home_pitcher_name,
                    '어웨이팀 선발' : away_pitcher_name,
                    '구장' : stadium
                }

                print(date,stadium)

                # array append
                game_result.append(game_dict)

                time.sleep(0.5)
                game_driver.quit()

        except :
            print('데이터 없음, 다음월 -----')
            continue
# Out:
# 1
# 2022 01
# tr >>>> 데이터가 없습니다.
# url error, 다음 경기 -----
# 1
# 2022 02
# tr >>>> 데이터가 없습니다.
# url error, 다음 경기 -----
# 1
# 2022 03
# tr >>>> 데이터가 없습니다.
# url error, 다음 경기 -----
# 25
# 2022 04
# tr >>>> 04.02(토) 14:00 한화4vs6두산 리뷰 하이라이트 MS-T
# SPO-2T 잠실 -
# 2022.04.02(토) 구장 : 잠실
# 2022 04
# tr >>>> 04.03(일) 14:00 한화0vs1두산 리뷰 하이라이트 SS-T 잠실 -
# 2022.04.03(일) 구장 : 잠실
# 2022 04
# tr >>>> 04.05(화) 18:30 삼성6vs5두산 리뷰 하이라이트 SPO-T 잠실 -
# 2022.04.05(화) 구장 : 잠실
# 2022 04
# tr >>>> 04.06(수) 18:30 삼성7vs1두산 리뷰 하이라이트 SPO-T 잠실 -
# 2022.04.06(수) 구장 : 잠실
# 2022 04
# tr >>>> 04.07(목) 18:30 삼성5vs6두산 리뷰 하이라이트 SPO-T 잠실 -
# 2022.04.07(목) 구장 : 잠실
# 2022 04
# tr >>>> 04.08(금) 18:30 두산6vs1롯데 리뷰 하이라이트 KN-T 사직 -
# 2022.04.08(금) 구장 : 사직
# 2022 04
# tr >>>> 04.09(토) 17:00 두산4vs5롯데 리뷰 하이라이트 KN-T 사직 -
# 2022.04.09(토) 구장 : 사직
# 2022 04
# tr >>>> 04.10(일) 14:00 두산4vs3롯데 리뷰 하이라이트 KN-T 사직 -
# 2022.04.10(일) 구장 : 사직
# 2022 04
# tr >>>> 04.12(화) 18:30 두산3vs1KT 리뷰 하이라이트 수원 -
# 2022.04.12(화) 구장 : 수원
# 2022 04
# tr >>>> 04.13(수) 18:30 두산vsKT SPO-2T 수원 우천취소
# url error, 다음 경기 -----
# 2022 04
# tr >>>> 04.14(목) 18:30 두산5vs4KT 리뷰 하이라이트 SPO-2T 수원 -
# 2022.04.14(목) 구장 : 수원
# 2022 04
# tr >>>> 04.15(금) 18:30 키움4vs2두산 리뷰 하이라이트 MS-T 잠실 -
# 2022.04.15(금) 구장 : 잠실
# 2022 04
# tr >>>> 04.16(토) 17:00 키움1vs4두산 리뷰 하이라이트 KN-T
# MS-T 잠실 -
# 2022.04.16(토) 구장 : 잠실
# 2022 04
# tr >>>> 04.17(일) 14:00 키움6vs2두산 리뷰 하이라이트 MS-T 잠실 -
# 2022.04.17(일) 구장 : 잠실
# 2022 04
# tr >>>> 04.19(화) 18:30 두산3vs6KIA 리뷰 하이라이트 MS-T
# G-CMB 광주 -
# 2022.04.19(화) 구장 : 광주
# 2022 04
# tr >>>> 04.20(수) 18:30 두산4vs3KIA 리뷰 하이라이트 MS-T
# G-CMB 광주 -
# 2022.04.20(수) 구장 : 광주
# 2022 04
# tr >>>> 04.21(목) 18:30 두산2vs1KIA 리뷰 하이라이트 MS-T
# G-CMB 광주 -
# 2022.04.21(목) 구장 : 광주
# 2022 04
# tr >>>> 04.22(금) 18:30 LG5vs1두산 리뷰 하이라이트 SPO-T 잠실 -
# 2022.04.22(금) 구장 : 잠실
# 2022 04
# tr >>>> 04.23(토) 17:00 LG2vs4두산 리뷰 하이라이트 SPO-T 잠실 -
# 2022.04.23(토) 구장 : 잠실
# 2022 04
# tr >>>> 04.24(일) 14:00 LG5vs0두산 리뷰 하이라이트 SPO-T 잠실 -
# tr >>>> 06.10(금) 18:30 두산7vs10LG 리뷰 하이라이트 SPO-T 잠실 -
# 2022.06.10(금) 구장 : 잠실
# 2022 06
# tr >>>> 06.11(토) 17:00 두산5vs4LG 리뷰 하이라이트 SPO-T 잠실 -
# 2022.06.11(토) 구장 : 잠실
# 2022 06
# tr >>>> 06.12(일) 17:00 두산6vs9LG 리뷰 하이라이트 SPO-T T-R 잠실 -
# 2022.06.12(일) 구장 : 잠실
# 2022 06
# tr >>>> 06.14(화) 18:30 두산0vs2키움 리뷰 하이라이트 KN-T 고척 -
# 2022.06.14(화) 구장 : 고척
# 2022 06
# tr >>>> 06.15(수) 18:30 두산4vs3키움 리뷰 하이라이트 KN-T 고척 -
# 2022.06.15(수) 구장 : 고척
# 2022 06
# tr >>>> 06.16(목) 18:30 두산2vs6키움 리뷰 하이라이트 KN-T 고척 -
# 2022.06.16(목) 구장 : 고척
# 2022 06
# tr >>>> 06.17(금) 18:30 KT4vs2두산 리뷰 하이라이트 SPO-2T 잠실 -
# 2022.06.17(금) 구장 : 잠실
# 2022 06
# tr >>>> 06.18(토) 17:00 KT0vs5두산 리뷰 하이라이트 SS-T
# SPO-2T 잠실 -
# 2022.06.18(토) 구장 : 잠실
# 2022 06
# tr >>>> 06.19(일) 17:00 KT7vs1두산 리뷰 하이라이트 SPO-2T 잠실 -
# 2022.06.19(일) 구장 : 잠실
# 2022 06
# tr >>>> 06.21(화) 18:30 두산16vs2SSG 리뷰 하이라이트 SPO-T 문학 -
# 2022.06.21(화) 구장 : 문학
# 2022 06
# tr >>>> 06.22(수) 18:30 두산5vs6SSG 리뷰 하이라이트 SPO-T 문학 -
# 2022.06.22(수) 구장 : 문학
# 2022 06
# tr >>>> 06.23(목) 18:30 두산vsSSG SPO-T 문학 우천취소
# url error, 다음 경기 -----
# 2022 06
# tr >>>> 06.24(금) 18:30 KIA4vs3두산 리뷰 하이라이트 SS-T 잠실 -
# 2022.06.24(금) 구장 : 잠실
# 2022 06
# tr >>>> 06.25(토) 17:00 KIA8vs6두산 리뷰 하이라이트 SS-T 잠실 -
# 2022.06.25(토) 구장 : 잠실
# 2022 06
# tr >>>> 06.26(일) 17:00 KIA4vs8두산 리뷰 하이라이트 SS-T 잠실 -
# 2022.06.26(일) 구장 : 잠실
# 2022 06
# tr >>>> 06.28(화) 18:30 두산3vs3롯데 리뷰 하이라이트 SS-T KNN-R
# PM-R 사직 -
# 2022.06.28(화) 구장 : 사직
# 2022 06
# tr >>>> 06.29(수) 18:30 두산vs롯데 SS-T KNN-R
# PM-R 사직 우천취소
# url error, 다음 경기 -----
# 2022 06
# tr >>>> 06.30(목) 18:30 두산1vs5롯데 리뷰 하이라이트 SS-T KNN-R
# PM-R 사직 -
# 2022.06.30(목) 구장 : 사직
# 21
# 2022 07
# tr >>>> 07.01(금) 18:30 두산7vs11KT 리뷰 하이라이트 SPO-2T 수원 -
# 2022.07.01(금) 구장 : 수원
# 2022 07
# tr >>>> 07.02(토) 18:00 두산3vs8KT 리뷰 하이라이트 SPO-2T 수원 -
# 2022.07.02(토) 구장 : 수원
# 2022 07
# tr >>>> 07.03(일) 17:00 두산0vs6KT 리뷰 하이라이트 SPO-2T 수원 -
# 2022.07.03(일) 구장 : 수원
# 2022 07
# tr >>>> 07.05(화) 18:30 키움4vs3두산 리뷰 하이라이트 SPO-T 잠실 -
# 2022.07.05(화) 구장 : 잠실
# 2022 07
# tr >>>> 07.06(수) 18:30 키움2vs5두산 리뷰 하이라이트 SPO-T 잠실 -
# 2022.07.06(수) 구장 : 잠실
# 2022 07
# tr >>>> 07.07(목) 18:30 키움2vs4두산 리뷰 하이라이트 SPO-T 잠실 -
# 2022.07.07(목) 구장 : 잠실
# 2022 07
# tr >>>> 07.08(금) 18:30 LG11vs4두산 리뷰 하이라이트 KN-T 잠실 -
# 2022.07.08(금) 구장 : 잠실
# 2022 07
# tr >>>> 07.09(토) 18:00 LG8vs6두산 리뷰 하이라이트 KN-T 잠실 -
# 2022.07.09(토) 구장 : 잠실
# 2022 07
# tr >>>> 07.10(일) 17:00 LG9vs0두산 리뷰 하이라이트 KN-T 잠실 -
# 2022.07.10(일) 구장 : 잠실
# 2022 07
# tr >>>> 07.12(화) 18:30 두산11vs7NC 리뷰 하이라이트 MS-T KM-R 창원 -
# 2022.07.12(화) 구장 : 창원
# 2022 07
# tr >>>> 07.13(수) 18:30 두산1vs4NC 리뷰 하이라이트 MS-T KM-R 창원 -
# 2022.07.13(수) 구장 : 창원
# 2022 07
# tr >>>> 07.14(목) 18:30 두산11vs3NC 리뷰 하이라이트 MS-T KM-R 창원 -
# 2022.07.14(목) 구장 : 창원
# 2022 07
# tr >>>> 07.22(금) 18:30 SSG1vs0두산 리뷰 하이라이트 SPO-T 잠실 -
# 2022.07.22(금) 구장 : 잠실
# 2022 07
# tr >>>> 07.23(토) 18:00 SSGvs두산 SPO-T 잠실 우천취소
# url error, 다음 경기 -----
# 2022 07
# tr >>>> 07.24(일) 17:00 SSG5vs4두산 리뷰 하이라이트 SPO-T 잠실 -
# 2022.07.24(일) 구장 : 잠실
# 2022 07
# tr >>>> 07.26(화) 18:30 롯데1vs6두산 리뷰 하이라이트 SPO-T KNN-R 잠실 -
# 2022.07.26(화) 구장 : 잠실
# 2022 07
# tr >>>> 07.27(수) 18:30 롯데5vs6두산 리뷰 하이라이트 SPO-T KNN-R 잠실 -
# 2022.07.27(수) 구장 : 잠실
# 2022 07
# tr >>>> 07.28(목) 18:30 롯데5vs8두산 리뷰 하이라이트 SPO-T KNN-R 잠실 -
# 2022.07.28(목) 구장 : 잠실
# 2022 07
# tr >>>> 07.29(금) 18:30 두산7vs3한화 리뷰 하이라이트 SPO-T
# D-CMB 대전 -
# 2022.07.29(금) 구장 : 대전
# 2022 07
# tr >>>> 07.30(토) 18:00 두산1vs11한화 리뷰 하이라이트 SPO-T
# D-CMB 대전 -
# 2022.07.30(토) 구장 : 대전
# 2022 07
# tr >>>> 07.31(일) 17:00 두산vs한화 SPO-T
# D-CMB 대전 우천취소
# url error, 다음 경기 -----
# 25
# 2022 08
# tr >>>> 08.02(화) 18:30 삼성vs두산 KN-T T-R 잠실 우천취소
# url error, 다음 경기 -----
# 2022 08
# tr >>>> 08.03(수) 18:30 삼성1vs3두산 리뷰 하이라이트 KN-T T-R 잠실 -
# 2022.08.03(수) 구장 : 잠실
# 2022 08
# tr >>>> 08.04(목) 18:30 삼성9vs2두산 리뷰 하이라이트 KN-T T-R 잠실 -
# 2022.08.04(목) 구장 : 잠실
# 2022 08
# tr >>>> 08.05(금) 18:30 두산5vs3KIA 리뷰 하이라이트 SPO-T
# G-CMB 광주 -
# 2022.08.05(금) 구장 : 광주
# 2022 08
# tr >>>> 08.06(토) 18:00 두산7vs4KIA 리뷰 하이라이트 SPO-T
# G-CMB 광주 -
# 2022.08.06(토) 구장 : 광주
# 2022 08
# tr >>>> 08.07(일) 17:00 두산4vs5KIA 리뷰 하이라이트 SPO-T
# G-CMB 광주 -
# 2022.08.07(일) 구장 : 광주
# 2022 08
# tr >>>> 08.10(수) 18:30 NC11vs0두산 리뷰 하이라이트 SS-T 잠실 -
# 2022.08.10(수) 구장 : 잠실
# 2022 08
# tr >>>> 08.11(목) 18:30 NC3vs2두산 리뷰 하이라이트 SS-T 잠실 -
# 2022.08.11(목) 구장 : 잠실
# 2022 08
# tr >>>> 08.12(금) 18:30 NC1vs7두산 리뷰 하이라이트 SS-T 잠실 -
# 2022.08.12(금) 구장 : 잠실
# 2022 08
# tr >>>> 08.13(토) 18:00 SSG8vs2두산 리뷰 하이라이트 MS-T 잠실 -
# 2022.08.13(토) 구장 : 잠실
# 2022 08
# tr >>>> 08.14(일) 17:00 SSG5vs4두산 리뷰 하이라이트 MS-T 잠실 -
# 2022.08.14(일) 구장 : 잠실
# 2022 08
# tr >>>> 08.16(화) 18:30 두산vs롯데 SS-T KNN-R
# PM-R 사직 우천취소
# url error, 다음 경기 -----
# 2022 08
# tr >>>> 08.17(수) 18:30 두산6vs8롯데 리뷰 하이라이트 SS-T KNN-R
# PM-R 사직 -
# 2022.08.17(수) 구장 : 사직
# 2022 08
# tr >>>> 08.18(목) 18:30 키움2vs10두산 리뷰 하이라이트 MS-T 잠실 -
# 2022.08.18(목) 구장 : 잠실
# 2022 08
# tr >>>> 08.19(금) 18:30 키움vs두산 MS-T 잠실 우천취소
# url error, 다음 경기 -----
# 2022 08
# tr >>>> 08.20(토) 18:00 두산1vs6LG 리뷰 하이라이트 SPO-2T 잠실 -
# 2022.08.20(토) 구장 : 잠실
# 2022 08
# tr >>>> 08.21(일) 17:00 두산4vs2LG 리뷰 하이라이트 SPO-2T 잠실 -
# 2022.08.21(일) 구장 : 잠실
# 2022 08
# tr >>>> 08.23(화) 18:30 KT2vs1두산 리뷰 하이라이트 SPO-T 잠실 -
# 2022.08.23(화) 구장 : 잠실
# 2022 08
# tr >>>> 08.24(수) 18:30 KT5vs1두산 리뷰 하이라이트 SPO-T 잠실 -
# 2022.08.24(수) 구장 : 잠실
# 2022 08
# tr >>>> 08.25(목) 18:30 두산0vs4한화 리뷰 하이라이트 SS-T
# D-CMB 대전 -
# 2022.08.25(목) 구장 : 대전
# 2022 08
# tr >>>> 08.26(금) 18:30 두산1vs2한화 리뷰 하이라이트 SS-T
산 리뷰 하이라이트 SPO-2T 잠실 -
# 2022.09.20(화) 구장 : 잠실
# 2022 09
# tr >>>> 09.21(수) 18:30 NC5vs1두산 리뷰 하이라이트 SPO-2T 잠실 -
# 2022.09.21(수) 구장 : 잠실
# 2022 09
# tr >>>> 09.22(목) 18:30 두산5vs2키움 리뷰 하이라이트 SPO-2T 고척 -
# 2022.09.22(목) 구장 : 고척
# 2022 09
# tr >>>> 09.23(금) 18:30 두산1vs5키움 리뷰 하이라이트 SPO-2T 고척 -
# 2022.09.23(금) 구장 : 고척
# 2022 09
# tr >>>> 09.24(토) 17:00 두산5vs14SSG 리뷰 하이라이트 KN-T
# SPO-2T 문학 -
# 2022.09.24(토) 구장 : 문학
# 2022 09
# tr >>>> 09.25(일) 14:00 한화3vs5두산 리뷰 하이라이트 SS-T 잠실 -
# 2022.09.25(일) 구장 : 잠실
# 2022 09
# tr >>>> 09.27(화) 18:30 두산4vs5KT 리뷰 하이라이트 KN-T
# SPO-2T 수원 -
# 2022.09.27(화) 구장 : 수원
# 2022 09
# tr >>>> 09.28(수) 18:30 두산0vs8KT 리뷰 하이라이트 SS-T
# SPO-2T 수원 -
# 2022.09.28(수) 구장 : 수원
# 2022 09
# tr >>>> 09.29(목) 18:30 두산6vs5한화 리뷰 하이라이트 MS-T
# D-CMB 대전 -
# 2022.09.29(목) 구장 : 대전
# 2022 09
# tr >>>> 09.30(금) 18:30 두산3vs11삼성 리뷰 하이라이트 MS-T
# SS-T T-R 대구 -
# 2022.09.30(금) 구장 : 대구
# 7
# 2022 10
# tr >>>> 10.01(토) 17:00 두산3vs4삼성 리뷰 하이라이트 SS-T
# SPO-T T-R 대구 -
# 2022.10.01(토) 구장 : 대구
# 2022 10
# tr >>>> 10.02(일) 14:00 두산1vs3롯데 리뷰 하이라이트 SPO-T KNN-R
# PM-R 사직 -
# 2022.10.02(일) 구장 : 사직
# 2022 10
# tr >>>> 10.03(월) 14:00 두산9vs3롯데 리뷰 하이라이트 KN-T KNN-R
# PM-R 사직 -
# 2022.10.03(월) 구장 : 사직
# 2022 10
# tr >>>> 10.05(수) 18:30 SSG2vs5두산 리뷰 하이라이트 SPO-2T 잠실 -
# 2022.10.05(수) 구장 : 잠실
# 2022 10
# tr >>>> 10.06(목) 18:30 삼성4vs5두산 리뷰 하이라이트 SPO-2T T-R 잠실 -
# 2022.10.06(목) 구장 : 잠실
# 2022 10
# tr >>>> 10.07(금) 18:30 삼성8vs2두산 리뷰 하이라이트 KN-T
# MS-T T-R 잠실 -
# 2022.10.07(금) 구장 : 잠실
# 2022 10
# tr >>>> 10.08(토) 17:00 키움5vs1두산 리뷰 하이라이트 MS-T 잠실 -
# 2022.10.08(토) 구장 : 잠실
# 1
# 2022 11
# tr >>>> 데이터가 없습니다.
# url error, 다음 경기 -----
# 1
# 2022 12
# tr >>>> 데이터가 없습니다.
# url error, 다음 경기 -----
# 1
# 2023 01
# tr >>>> 데이터가 없습니다.
# url error, 다음 경기 -----
# 1
# 2023 02
# tr >>>> 데이터가 없습니다.
# url error, 다음 경기 -----
# 1
# 2023 03
# tr >>>> 데이터가 없습니다.
# url error, 다음 경기 -
산 리뷰 하이라이트 SPO-2T 잠실 -
# 2023.08.06(일) 구장 : 잠실
# 2023 08
# tr >>>> 08.08(화) 18:30 삼성3vs5두산 리뷰 하이라이트 SS-T 잠실 -
# 2023.08.08(화) 구장 : 잠실
# 2023 08
# tr >>>> 08.09(수) 18:30 삼성6vs4두산 리뷰 하이라이트 SS-T 잠실 -
# 2023.08.09(수) 구장 : 잠실
# 2023 08
# tr >>>> 08.10(목) 18:30 삼성vs두산 SS-T 잠실 우천취소
# url error, 다음 경기 -----
# 2023 08
# tr >>>> 08.11(금) 18:30 두산11vs4한화 리뷰 하이라이트 SPO-2T 대전 -
# 2023.08.11(금) 구장 : 대전
# 2023 08
# tr >>>> 08.12(토) 18:00 두산1vs6한화 리뷰 하이라이트 SPO-2T 대전 -
# 2023.08.12(토) 구장 : 대전
# 2023 08
# tr >>>> 08.13(일) 17:00 두산3vs8한화 리뷰 하이라이트 SPO-2T 대전 -
# 2023.08.13(일) 구장 : 대전
# 2023 08
# tr >>>> 08.15(화) 17:00 KT1vs0두산 리뷰 하이라이트 KN-T 잠실 -
# 2023.08.15(화) 구장 : 잠실
# 2023 08
# tr >>>> 08.16(수) 18:30 KT5vs2두산 리뷰 하이라이트 KN-T 잠실 -
# 2023.08.16(수) 구장 : 잠실
# 2023 08
# tr >>>> 08.17(목) 18:30 KT9vs8두산 리뷰 하이라이트 KN-T 잠실 -
# 2023.08.17(목) 구장 : 잠실
# 2023 08
# tr >>>> 08.18(금) 18:30 NCvs두산 SPO-2T 잠실 우천취소
# url error, 다음 경기 -----
# 2023 08
# tr >>>> 08.19(토) 18:00 NC1vs4두산 리뷰 하이라이트 SPO-2T
# MS-T 잠실 -
# 2023.08.19(토) 구장 : 잠실
# 2023 08
# tr >>>> 08.20(일) 17:00 NC12vs5두산 리뷰 하이라이트 SPO-2T
# MS-T 잠실 -
# 2023.08.20(일) 구장 : 잠실
# 2023 08
# tr >>>> 08.22(화) 18:30 두산6vs1키움 리뷰 하이라이트 SPO-T 고척 -
# 2023.08.22(화) 구장 : 고척
# 2023 08
# tr >>>> 08.23(수) 18:30 두산11vs4키움 리뷰 하이라이트 SPO-T 고척 -
# 2023.08.23(수) 구장 : 고척
# 2023 08
# tr >>>> 08.24(목) 18:30 두산8vs6키움 리뷰 하이라이트 SPO-T 고척 -
# 2023.08.24(목) 구장 : 고척
# 2023 08
# tr >>>> 08.25(금) 18:30 SSG1vs10두산 리뷰 하이라이트 KN-T 잠실 -
# 2023.08.25(금) 구장 : 잠실
# 2023 08
# tr >>>> 08.26(토) 18:00 SSG7vs5두산 리뷰 하이라이트 KN-T 잠실 -
# 2023.08.26(토) 구장 : 잠실
# 2023 08
# tr >>>> 08.27(일) 17:00 SSG8vs5두산 리뷰 하이라이트 KN-T 잠실 -
# 2023.08.27(일) 구장 : 잠실
# 2023 08
# tr >>>> 08.29(화) 18:30 두산vsLG SPO-T 잠실 우천취소
# url error, 다음 경기 -----
# 2023 08
# tr >>>> 08.30(수) 18:30 두산vsLG SPO-T 잠실 우천취소
# url error, 다음 경기 -----
# 2023 08
# tr >>>> 08.31(목) 18:30 두산2vs3LG 리뷰 하이라이트 SPO-T 잠실 -
# 2023.08.31(목) 구장 : 잠실
# 29
# 2023 09
# tr >>>> 09.01(금) 18:30 두산vs롯데 SPO-T 사직 우천취소
# url error, 다음 경기 -----
# 2023 09
# tr >>>> 09.02(토) 17:00 두산vs롯데 KN-T 사직 우천취소
# url error, 다음 경기 -----
# 2023 09
# tr >>>> 09.03(일) 14:00 두산2vs0롯데 리뷰 하이라이트 SPO-T 사직 -
# 2023.09.03(일) 구장 : 사직
# SS-T 창원 -
# 2023.09.24(일) 구장 : 창원
# 2023 09
# tr >>>> 09.26(화) 18:30 두산vsSSG SPO-2T 문학 우천취소
# url error, 다음 경기 -----
# 2023 09
# tr >>>> 09.27(수) 15:00 두산7vs7SSG 리뷰 하이라이트 SPO-2T 문학 -
# 2023.09.27(수) 구장 : 문학
# 2023 09
# tr >>>> 18:30 두산3vs6SSG 리뷰 하이라이트 SPO-2T 문학 -
# 2023.09.27(수) 구장 : 문학
# 2023 09
# tr >>>> 09.29(금) 14:00 LG3vs4두산 리뷰 하이라이트 SS-T
# SPO-2T 잠실 -
# 2023.09.29(금) 구장 : 잠실
# 2023 09
# tr >>>> 09.30(토) 14:00 LG1vs3두산 리뷰 하이라이트 MS-T
# SS-T 잠실 -
# 2023.09.30(토) 구장 : 잠실
# 13
# 2023 10
# tr >>>> 10.01(일) 14:00 LG7vs4두산 리뷰 하이라이트 SPO-T 잠실 -
# 2023.10.01(일) 구장 : 잠실
# 2023 10
# tr >>>> 10.02(월) 14:00 키움2vs7두산 리뷰 하이라이트 SS-T
# SPO-T 잠실 -
# 2023.10.02(월) 구장 : 잠실
# 2023 10
# tr >>>> 10.03(화) 14:00 키움6vs5두산 리뷰 하이라이트 KN-T 잠실 -
# 2023.10.03(화) 구장 : 잠실
# 2023 10
# tr >>>> 10.07(토) 17:00 롯데6vs3두산 리뷰 하이라이트 SS-T 잠실 -
# 2023.10.07(토) 구장 : 잠실
# 2023 10
# tr >>>> 10.08(일) 14:00 롯데1vs2두산 리뷰 하이라이트 SS-T 잠실 -
# 2023.10.08(일) 구장 : 잠실
# 2023 10
# tr >>>> 10.10(화) 18:30 두산4vs5KT 리뷰 하이라이트 SPO-T 수원 -
# 2023.10.10(화) 구장 : 수원
# 2023 10
# tr >>>> 10.11(수) 18:30 두산3vs14롯데 리뷰 하이라이트 SPO-T
# SPO-2T KNN-R
# PM-R 사직 -
# 2023.10.11(수) 구장 : 사직
# 2023 10
# tr >>>> 10.12(목) 18:30 NC1vs11두산 리뷰 하이라이트 SS-T
# KN-T
# SPO-2T 잠실 -
# 2023.10.12(목) 구장 : 잠실
# 2023 10
# tr >>>> 10.13(금) 18:30 KIA1vs3두산 리뷰 하이라이트 SPO-T 잠실 -
# 2023.10.13(금) 구장 : 잠실
# 2023 10
# tr >>>> 10.14(토) 17:00 두산3vs2LG 리뷰 하이라이트 SS-T 잠실 -
# 2023.10.14(토) 구장 : 잠실
# 2023 10
# tr >>>> 10.15(일) 14:00 두산2vs5LG 리뷰 하이라이트 MS-T 잠실 -
# 2023.10.15(일) 구장 : 잠실
# 2023 10
# tr >>>> 10.16(월) 18:30 SSG3vs2두산 리뷰 하이라이트 SPO-2T 잠실 -
# 2023.10.16(월) 구장 : 잠실
# 2023 10
# tr >>>> 10.17(화) 18:30 두산0vs5SSG 리뷰 하이라이트 SPO-2T 문학 -
# 2023.10.17(화) 구장 : 문학
# 1
# 2023 11
# tr >>>> 데이터가 없습니다.
# url error, 다음 경기 -----
# 1
# 2023 12
# tr >>>> 데이터가 없습니다.
# url error, 다음 경기 -----
# 1
# 2024 01
# tr >>>> 데이터가 없습니다.
# url error, 다음 경기 -----
# 1
# 2024 02
# tr >>>> 데이터가 없습니다.
# url error, 다음 경기 -----
# 8
# 2024 03
# tr >>>> 03.23(토) 14:00 두산3vs4NC 리뷰 하이라이트 KN-T
# SPO-T
# SPO-2T 창원 -
# 2024.03.23(토) 구장 : 창원
# 2024 03
# tr >>>> 03.24(일) 14:00 두산6vs3NC 리뷰 하이라이트 SPO-T 창원 -
# 2024.03.24(일) 구장 : 창원
# 2024 03
# tr >>>> 03.26(화) 18:30 두산8vs5KT 리뷰 하이라이트 TVING 수원 -
# 2024.03.26(화) 구장 : 수원
# 2024 03
# tr >>>> 03.27(수) 18:30 두산11vs8KT 리뷰 하이라이트 KN-T 수원 -
# 2024.03.27(수) 구장 : 수원
# 2024 03
# tr >>>> 03.28(목) 18:30 두산7vs8KT 리뷰 하이라이트 TVING 수원 -
# 2024.03.28(목) 구장 : 수원
# 2024 03
# tr >>>> 03.29(금) 18:30 KIA4vs2두산 리뷰 하이라이트 SPO-2T 잠실 -
# 2024.03.29(금) 구장 : 잠실
# 2024 03
# tr >>>> 03.30(토) 17:00 KIA0vs8두산 리뷰 하이라이트 SPO-2T 잠실 -
# 2024.03.30(토) 구장 : 잠실
# 2024 03
# tr >>>> 03.31(일) 14:00 KIA9vs3두산 리뷰 하이라이트 SPO-2T 잠실 -
# 2024.03.31(일) 구장 : 잠실
# 26
# 2024 04
# tr >>>> 04.02(화) 18:30 두산6vs13SSG 리뷰 하이라이트 SPO-T 문학 -
# 2024.04.02(화) 구장 : 문학
# 2024 04
# tr >>>> 04.03(수) 18:30 두산3vs5SSG 리뷰 하이라이트 SPO-T 문학 -
# 2024.04.03(수) 구장 : 문학
# 2024 04
# tr >>>> 04.04(목) 18:30 두산2vs3SSG 리뷰 하이라이트 SPO-T 문학 -
# 2024.04.04(목) 구장 : 문학
# 2024 04
# tr >>>> 04.05(금) 18:30 두산4vs3롯데 리뷰 하이라이트 SPO-2T 사직 -
# 2024.04.05(금) 구장 : 사직
# 2024 04
# tr >>>> 04.06(토) 17:00 두산1vs8롯데 리뷰 하이라이트 SPO-2T 사직 -
# 2024.04.06(토) 구장 : 사직
# 2024 04
# tr >>>> 04.07(일) 14:00 두산6vs7롯데 리뷰 하이라이트 M-T 사직 -
# 2024.04.07(일) 구장 : 사직
# 2024 04
# tr >>>> 04.09(화) 18:30 한화3vs5두산 리뷰 하이라이트 SPO-T 잠실 -
# 2024.04.09(화) 구장 : 잠실
# 2024 04
# tr >>>> 04.10(수) 14:00 한화4vs7두산 리뷰 하이라이트 SPO-T 잠실 -
# 2024.04.10(수) 구장 : 잠실
# 2024 04
# tr >>>> 04.11(목) 18:30 한화3vs0두산 리뷰 하이라이트 SPO-T 잠실 -
# 2024.04.11(목) 구장 : 잠실
# 2024 04
# tr >>>> 04.12(금) 18:30 LG2vs1두산 리뷰 하이라이트 SPO-T 잠실 -
# 2024.04.12(금) 구장 : 잠실
# 2024 04
# tr >>>> 04.13(토) 17:00 LG2vs5두산 리뷰 하이라이트 KN-T 잠실 -
# 2024.04.13(토) 구장 : 잠실
# 2024 04
# tr >>>> 04.14(일) 14:00 LG5vs9두산 리뷰 하이라이트 KN-T 잠실 -
# 2024.04.14(일) 구장 : 잠실
# 2024 04
# tr >>>> 04.16(화) 18:30 두산5vs7삼성 리뷰 하이라이트 SS-T 대구 -
# 2024.05.08(수) 구장 : 고척
# 2024 05
# tr >>>> 05.09(목) 18:30 두산5vs2키움 리뷰 하이라이트 KN-T 고척 -
# 2024.05.09(목) 구장 : 고척
# 2024 05
# tr >>>> 05.10(금) 18:30 KT3vs7두산 리뷰 하이라이트 KN-T 잠실 -
# 2024.05.10(금) 구장 : 잠실
# 2024 05
# tr >>>> 05.11(토) 17:00 KTvs두산 SPO-2T
# KN-T 잠실 우천취소
# url error, 다음 경기 -----
# 2024 05
# tr >>>> 05.12(일) 14:00 KT4vs12두산 리뷰 하이라이트 SPO-2T
# KN-T 잠실 -
# 2024.05.12(일) 구장 : 잠실
# 2024 05
# tr >>>> 17:00 KT4vs8두산 리뷰 하이라이트 SPO-2T 잠실 -
# 2024.05.12(일) 구장 : 잠실
# 2024 05
# tr >>>> 05.14(화) 18:30 두산8vs5KIA 리뷰 하이라이트 SPO-2T 광주 -
# 2024.05.14(화) 구장 : 광주
# 2024 05
# tr >>>> 05.15(수) 14:00 두산4vs8KIA 리뷰 하이라이트 S-T 광주 -
# 2024.05.15(수) 구장 : 광주
# 2024 05
# tr >>>> 05.16(목) 18:30 두산7vs7KIA 리뷰 하이라이트 SPO-2T 광주 -
# 2024.05.16(목) 구장 : 광주
# 2024 05
# tr >>>> 05.17(금) 18:30 롯데5vs1두산 리뷰 하이라이트 KN-T 잠실 -
# 2024.05.17(금) 구장 : 잠실
# 2024 05
# tr >>>> 05.18(토) 17:00 롯데3vs8두산 리뷰 하이라이트 KN-T 잠실 -
# 2024.05.18(토) 구장 : 잠실
# 2024 05
# tr >>>> 05.19(일) 14:00 롯데3vs3두산 리뷰 하이라이트 SPO-2T 잠실 -
# 2024.05.19(일) 구장 : 잠실
# 2024 05
# tr >>>> 05.21(화) 18:30 SSG6vs8두산 리뷰 하이라이트 SPO-2T 잠실 -
# 2024.05.21(화) 구장 : 잠실
# 2024 05
# tr >>>> 05.22(수) 18:30 SSG1vs3두산 리뷰 하이라이트 SPO-2T 잠실 -
# 2024.05.22(수) 구장 : 잠실
# 2024 05
# tr >>>> 05.23(목) 18:30 SSG3vs10두산 리뷰 하이라이트 SPO-2T 잠실 -
# 2024.05.23(목) 구장 : 잠실
# 2024 05
# tr >>>> 05.24(금) 18:30 두산7vs5KIA 리뷰 하이라이트 SS-T 광주 -
# 2024.05.24(금) 구장 : 광주
# 2024 05
# tr >>>> 05.25(토) 14:00 두산2vs6KIA 리뷰 하이라이트 S-T 광주 -
# 2024.05.25(토) 구장 : 광주
# 2024 05
# tr >>>> 05.26(일) 14:00 두산2vs5KIA 리뷰 하이라이트 SS-T 광주 -
# 2024.05.26(일) 구장 : 광주
# 2024 05
# tr >>>> 05.28(화) 18:30 KT12vs3두산 리뷰 하이라이트 SPO-2T 잠실 -
# 2024.05.28(화) 구장 : 잠실
# 2024 05
# tr >>>> 05.29(수) 18:30 KT6vs12두산 리뷰 하이라이트 SPO-2T 잠실 -
# 2024.05.29(수) 구장 : 잠실
# 2024 05
# tr >>>> 05.30(목) 18:30 KT1vs6두산 리뷰 하이라이트 SPO-2T 잠실 -
# 2024.05.30(목) 구장 : 잠실
# 2024 05
# tr >>>> 05.31(금) 18:30 LG6vs3두산 리뷰 하이라이트 SPO-T 잠실 -
# 2024.05.31(금) 구장 : 잠실
# 26
# 2024 06
# tr >>>> 06.01(토) 17:00 LG8vs5두산 리뷰 하이라이트 SPO-T 잠실 -
# 2024.06.01(토) 구장 : 잠실
# 2024 06
# tr >>>> 06.02(일) 14:00 LG9vs1두산 리뷰 하이라이트 M-T 잠실 -
# 2024.06.02(일) 구장 : 잠실
# 2024 06
# tr >>>> 06.04(화) 18:30 두산vsNC 프리뷰 KN-T 창원 -
# 데이터 없음, 다음월 -----
# 23
# 2024 07
# tr >>>> 07.02(화) 18:30 롯데vs두산 잠실 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.03(수) 18:30 롯데vs두산 잠실 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.04(목) 18:30 롯데vs두산 잠실 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.09(화) 18:30 두산vsKT 수원 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.10(수) 18:30 두산vsKT 수원 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.11(목) 18:30 두산vsKT 수원 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.12(금) 18:30 삼성vs두산 잠실 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.13(토) 18:00 삼성vs두산 잠실 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.14(일) 17:00 삼성vs두산 잠실 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.16(화) 18:30 두산vs롯데 울산 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.17(수) 18:30 두산vs롯데 울산 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.18(목) 18:30 두산vs롯데 울산 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.19(금) 18:30 두산vsLG 잠실 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.20(토) 18:00 두산vsLG 잠실 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.21(일) 17:00 두산vsLG 잠실 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.23(화) 18:30 키움vs두산 잠실 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.24(수) 18:30 키움vs두산 잠실 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.25(목) 18:30 키움vs두산 잠실 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.26(금) 18:30 두산vsSSG 문학 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.27(토) 18:00 두산vsSSG 문학 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.28(일) 17:00 두산vsSSG 문학 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.30(화) 18:30 두산vsKIA 광주 -
# url error, 다음 경기 -----
# 2024 07
# tr >>>> 07.31(수) 18:30 두산vsKIA 광주 -
# url error, 다음 경기 -----
# 25
# 2024 08
# tr >>>> 08.01(목) 18:30 두산vsKIA 광주 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.02(금) 18:30 키움vs두산 잠실 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.03(토) 18:00 키움vs두산 잠실 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.04(일) 17:00 키움vs두산 잠실 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.06(화) 18:30 LGvs두산 잠실 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.07(수) 18:30 LGvs두산 잠실 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.08(목) 18:30 LGvs두산 잠실 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.09(금) 18:30 두산vsSSG 문학 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.10(토) 18:00 두산vsSSG 문학 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.11(일) 17:00 두산vsSSG 문학 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.13(화) 18:30 롯데vs두산 잠실 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.14(수) 18:30 롯데vs두산 잠실 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.15(목) 17:00 롯데vs두산 잠실 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.16(금) 18:30 두산vsKT 수원 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.17(토) 18:00 두산vsKT 수원 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.18(일) 17:00 두산vsKT 수원 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.20(화) 18:30 두산vs삼성 포항 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.21(수) 18:30 두산vs삼성 포항 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.22(목) 18:30 두산vs삼성 포항 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.23(금) 18:30 한화vs두산 잠실 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.24(토) 18:00 한화vs두산 잠실 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.25(일) 17:00 한화vs두산 잠실 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.27(화) 18:30 두산vsNC 창원 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.28(수) 18:30 두산vsNC 창원 -
# url error, 다음 경기 -----
# 2024 08
# tr >>>> 08.29(목) 18:30 두산vsNC 창원 -
# url error, 다음 경기 -----
# 1
# 2024 09
# tr >>>> 데이터가 없습니다.
# url error, 다음 경기 -----
# 1
# 2024 10
# tr >>>> 데이터가 없습니다.
# url error, 다음 경기 -----
# 1
# 2024 11
# tr >>>> 데이터가 없습니다.
# url error, 다음 경기 -----
# 1
# 2024 12
# tr >>>> 데이터가 없습니다.
# url error, 다음 경기 -----

# %%
import pandas as pd

# %%
game_result
# Out:
# [{'날짜': '2022.04.02(토)',
#   '시작시간': '14:02',
#   '종료시간': '17:27',
#   '경기시간': '3:25',
#   '홈팀 선발': '스탁',
#   '어웨이팀 선발': '김민우',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.04.03(일)',
#   '시작시간': '14:01',
#   '종료시간': '16:29',
#   '경기시간': '2:28',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '킹험',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.04.05(화)',
#   '시작시간': '18:32',
#   '종료시간': '22:26',
#   '경기시간': '3:54',
#   '홈팀 선발': '이영하',
#   '어웨이팀 선발': '원태인',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.04.06(수)',
#   '시작시간': '18:31',
#   '종료시간': '21:31',
#   '경기시간': '3:00',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '양창섭',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.04.07(목)',
#   '시작시간': '18:31',
#   '종료시간': '22:24',
#   '경기시간': '3:53',
#   '홈팀 선발': '박신지',
#   '어웨이팀 선발': '허윤동',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.04.08(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:45',
#   '경기시간': '3:15',
#   '홈팀 선발': '이승헌',
#   '어웨이팀 선발': '스탁',
#   '구장': '구장 : 사직'},
#  {'날짜': '2022.04.09(토)',
#   '시작시간': '17:00',
#   '종료시간': '20:03',
#   '경기시간': '3:03',
#   '홈팀 선발': '박세웅',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 사직'},
#  {'날짜': '2022.04.10(일)',
#   '시작시간': '14:02',
#   '종료시간': '18:07',
#   '경기시간': '4:05',
#   '홈팀 선발': '스파크맨',
#   '어웨이팀 선발': '이영하',
#   '구장': '구장 : 사직'},
#  {'날짜': '2022.04.12(화)',
#   '시작시간': '18:31',
#   '종료시간': '21:42',
#   '경기시간': '3:11',
#   '홈팀 선발': '고영표',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 수원'},
#  {'날짜': '2022.04.14(목)',
#   '시작시간': '18:30',
#   '종료시간': '22:06',
#   '경기시간': '3:36',
#   '홈팀 선발': '소형준',
#   '어웨이팀 선발': '스탁',
#   '구장': '구장 : 수원'},
#  {'날짜': '2022.04.15(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:28',
#   '경기시간': '2:58',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '애플러',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.04.16(토)',
#   '시작시간': '17:01',
#   '종료시간': '20:11',
#   '경기시간': '3:10',
#   '홈팀 선발': '이영하',
#   '어웨이팀 선발': '요키시',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.04.17(일)',
#   '시작시간': '14:01',
#   '종료시간': '17:41',
#   '경기시간': '3:40',
#   '홈팀 선발': '미란다',
#   '어웨이팀 선발': '최원태',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.04.19(화)',
#   '시작시간': '18:29',
#   '종료시간': '22:10',
#   '경기시간': '3:41',
#   '홈팀 선발': '한승혁',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 광주'},
#  {'날짜': '2022.04.20(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:56',
#   '경기시간': '3:26',
#   '홈팀 선발': '양현종',
#   '어웨이팀 선발': '스탁',
#   '구장': '구장 : 광주'},
#  {'날짜': '2022.04.21(목)',
#   '시작시간': '18:30',
#   '종료시간': '21:18',
#   '경기시간': '2:48',
#   '홈팀 선발': '놀린',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 광주'},
#  {'날짜': '2022.04.22(금)',
#   '시작시간': '18:30',
#   '종료시간': '22:02',
#   '경기시간': '3:32',
#   '홈팀 선발': '이영하',
#   '어웨이팀 선발': '켈리',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.04.23(토)',
#   '시작시간': '17:01',
#   '종료시간': '20:02',
#   '경기시간': '3:01',
#   '홈팀 선발': '미란다',
#   '어웨이팀 선발': '임준형',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.04.24(일)',
#   '시작시간': '14:01',
#   '종료시간': '17:28',
#   '경기시간': '3:27',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '임찬규',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.04.26(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:42',
#   '경기시간': '3:12',
#   '홈팀 선발': '스탁',
#   '어웨이팀 선발': '루친스키',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.04.27(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:48',
#   '경기시간': '3:18',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '파슨스',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.04.28(목)',
#   '시작시간': '18:30',
#   '종료시간': '22:03',
#   '경기시간': '3:33',
#   '홈팀 선발': '이영하',
#   '어웨이팀 선발': '김시훈',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.04.29(금)',
#   '시작시간': '18:30',
#   '종료시간': '23:21',
#   '경기시간': '4:51',
#   '홈팀 선발': '노바',
#   '어웨이팀 선발': '최승용',
#   '구장': '구장 : 문학'},
#  {'날짜': '2022.04.30(토)',
#   '시작시간': '17:01',
#   '종료시간': '20:15',
#   '경기시간': '3:14',
#   '홈팀 선발': '오원석',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 문학'},
#  {'날짜': '2022.05.01(일)',
#   '시작시간': '14:00',
#   '종료시간': '16:45',
#   '경기시간': '2:45',
#   '홈팀 선발': '폰트',
#   '어웨이팀 선발': '스탁',
#   '구장': '구장 : 문학'},
#  {'날짜': '2022.05.03(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:38',
#   '경기시간': '3:08',
#   '홈팀 선발': '플럿코',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.05.04(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:45',
#   '경기시간': '3:15',
#   '홈팀 선발': '이민호',
#   '어웨이팀 선발': '이영하',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.05.05(목)',
#   '시작시간': '14:01',
#   '종료시간': '17:22',
#   '경기시간': '3:21',
#   '홈팀 선발': '켈리',
#   '어웨이팀 선발': '최승용',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.05.06(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:25',
#   '경기시간': '2:55',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '고영표',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.05.07(토)',
#   '시작시간': '17:01',
#   '종료시간': '21:17',
#   '경기시간': '4:16',
#   '홈팀 선발': '스탁',
#   '어웨이팀 선발': '데스파이네',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.05.08(일)',
#   '시작시간': '14:00',
#   '종료시간': '17:21',
#   '경기시간': '3:21',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '소형준',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.05.10(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:53',
#   '경기시간': '3:23',
#   '홈팀 선발': '애플러',
#   '어웨이팀 선발': '이영하',
#   '구장': '구장 : 고척'},
#  {'날짜': '2022.05.11(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:30',
#   '경기시간': '3:00',
#   '홈팀 선발': '최원태',
#   '어웨이팀 선발': '최승용',
#   '구장': '구장 : 고척'},
#  {'날짜': '2022.05.12(목)',
#   '시작시간': '18:30',
#   '종료시간': '21:47',
#   '경기시간': '3:17',
#   '홈팀 선발': '정찬헌',
#   '어웨이팀 선발': '박신지',
#   '구장': '구장 : 고척'},
#  {'날짜': '2022.05.14(토)',
#   '시작시간': '17:01',
#   '종료시간': '19:27',
#   '경기시간': '2:26',
#   '홈팀 선발': '뷰캐넌',
#   '어웨이팀 선발': '스탁',
#   '구장': '구장 : 대구'},
#  {'날짜': '2022.05.15(일)',
#   '시작시간': '14:01',
#   '종료시간': '17:09',
#   '경기시간': '3:08',
#   '홈팀 선발': '수아레즈',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 대구'},
#  {'날짜': '2022.05.17(화)',
#   '시작시간': '18:31',
#   '종료시간': '23:19',
#   '경기시간': '4:48',
#   '홈팀 선발': '이영하',
#   '어웨이팀 선발': '노바',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.05.18(수)',
#   '시작시간': '18:31',
#   '종료시간': '23:15',
#   '경기시간': '4:44',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '오원석',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.05.19(목)',
#   '시작시간': '18:30',
#   '종료시간': '21:49',
#   '경기시간': '3:19',
#   '홈팀 선발': '최승용',
#   '어웨이팀 선발': '폰트',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.05.20(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:27',
#   '경기시간': '2:57',
#   '홈팀 선발': '스탁',
#   '어웨이팀 선발': '나균안',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.05.21(토)',
#   '시작시간': '14:00',
#   '종료시간': '17:04',
#   '경기시간': '3:04',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '박세웅',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.05.22(일)',
#   '시작시간': '14:01',
#   '종료시간': '17:57',
#   '경기시간': '3:56',
#   '홈팀 선발': '이영하',
#   '어웨이팀 선발': '스파크맨',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.05.24(화)',
#   '시작시간': '18:29',
#   '종료시간': '21:26',
#   '경기시간': '2:57',
#   '홈팀 선발': '김민우',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 대전'},
#  {'날짜': '2022.05.25(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:33',
#   '경기시간': '3:03',
#   '홈팀 선발': '카펜터',
#   '어웨이팀 선발': '최승용',
#   '구장': '구장 : 대전'},
#  {'날짜': '2022.05.26(목)',
#   '시작시간': '18:29',
#   '종료시간': '22:16',
#   '경기시간': '3:47',
#   '홈팀 선발': '윤대경',
#   '어웨이팀 선발': '스탁',
#   '구장': '구장 : 대전'},
#  {'날짜': '2022.05.27(금)',
#   '시작시간': '18:29',
#   '종료시간': '21:37',
#   '경기시간': '3:08',
#   '홈팀 선발': '김시훈',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 창원'},
#  {'날짜': '2022.05.28(토)',
#   '시작시간': '17:00',
#   '종료시간': '20:13',
#   '경기시간': '3:13',
#   '홈팀 선발': '구창모',
#   '어웨이팀 선발': '이영하',
#   '구장': '구장 : 창원'},
#  {'날짜': '2022.05.29(일)',
#   '시작시간': '14:00',
#   '종료시간': '17:14',
#   '경기시간': '3:14',
#   '홈팀 선발': '신민혁',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 창원'},
#  {'날짜': '2022.05.31(화)',
#   '시작시간': '18:30',
#   '종료시간': '22:18',
#   '경기시간': '3:48',
#   '홈팀 선발': '최승용',
#   '어웨이팀 선발': '양현종',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.06.01(수)',
#   '시작시간': '17:00',
#   '종료시간': '20:13',
#   '경기시간': '3:13',
#   '홈팀 선발': '스탁',
#   '어웨이팀 선발': '로니',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.06.02(목)',
#   '시작시간': '18:31',
#   '종료시간': '21:47',
#   '경기시간': '3:16',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '임기영',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.06.03(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:51',
#   '경기시간': '3:21',
#   '홈팀 선발': '허윤동',
#   '어웨이팀 선발': '이영하',
#   '구장': '구장 : 대구'},
#  {'날짜': '2022.06.04(토)',
#   '시작시간': '17:01',
#   '종료시간': '20:54',
#   '경기시간': '3:53',
#   '홈팀 선발': '황동재',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 대구'},
#  {'날짜': '2022.06.07(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:26',
#   '경기시간': '2:56',
#   '홈팀 선발': '스탁',
#   '어웨이팀 선발': '남지민',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.06.08(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:43',
#   '경기시간': '3:13',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '윤대경',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.06.09(목)',
#   '시작시간': '18:31',
#   '종료시간': '22:32',
#   '경기시간': '4:01',
#   '홈팀 선발': '이영하',
#   '어웨이팀 선발': '문동주',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.06.10(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:48',
#   '경기시간': '3:18',
#   '홈팀 선발': '켈리',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.06.11(토)',
#   '시작시간': '17:01',
#   '종료시간': '20:37',
#   '경기시간': '3:36',
#   '홈팀 선발': '김윤식',
#   '어웨이팀 선발': '최승용',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.06.12(일)',
#   '시작시간': '17:00',
#   '종료시간': '20:57',
#   '경기시간': '3:57',
#   '홈팀 선발': '임준형',
#   '어웨이팀 선발': '스탁',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.06.14(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:28',
#   '경기시간': '2:58',
#   '홈팀 선발': '요키시',
#   '어웨이팀 선발': '박신지',
#   '구장': '구장 : 고척'},
#  {'날짜': '2022.06.15(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:42',
#   '경기시간': '3:12',
#   '홈팀 선발': '애플러',
#   '어웨이팀 선발': '이영하',
#   '구장': '구장 : 고척'},
#  {'날짜': '2022.06.16(목)',
#   '시작시간': '18:29',
#   '종료시간': '22:07',
#   '경기시간': '3:38',
#   '홈팀 선발': '최원태',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 고척'},
#  {'날짜': '2022.06.17(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:56',
#   '경기시간': '3:26',
#   '홈팀 선발': '최승용',
#   '어웨이팀 선발': '고영표',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.06.18(토)',
#   '시작시간': '17:00',
#   '종료시간': '20:03',
#   '경기시간': '3:03',
#   '홈팀 선발': '스탁',
#   '어웨이팀 선발': '데스파이네',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.06.19(일)',
#   '시작시간': '17:02',
#   '종료시간': '19:57',
#   '경기시간': '2:55',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '소형준',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.06.21(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:48',
#   '경기시간': '3:18',
#   '홈팀 선발': '이건욱',
#   '어웨이팀 선발': '이영하',
#   '구장': '구장 : 문학'},
#  {'날짜': '2022.06.22(수)',
#   '시작시간': '18:30',
#   '종료시간': '22:04',
#   '경기시간': '3:34',
#   '홈팀 선발': '오원석',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 문학'},
#  {'날짜': '2022.06.24(금)',
#   '시작시간': '18:31',
#   '종료시간': '22:35',
#   '경기시간': '4:04',
#   '홈팀 선발': '스탁',
#   '어웨이팀 선발': '한승혁',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.06.25(토)',
#   '시작시간': '17:01',
#   '종료시간': '21:24',
#   '경기시간': '4:23',
#   '홈팀 선발': '미란다',
#   '어웨이팀 선발': '로니',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.06.26(일)',
#   '시작시간': '17:00',
#   '종료시간': '20:21',
#   '경기시간': '3:21',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '임기영',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.06.28(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:25',
#   '경기시간': '2:23',
#   '홈팀 선발': '스파크맨',
#   '어웨이팀 선발': '이영하',
#   '구장': '구장 : 사직'},
#  {'날짜': '2022.06.30(목)',
#   '시작시간': '18:30',
#   '종료시간': '21:26',
#   '경기시간': '2:56',
#   '홈팀 선발': '이인복',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 사직'},
#  {'날짜': '2022.07.01(금)',
#   '시작시간': '18:30',
#   '종료시간': '22:10',
#   '경기시간': '3:40',
#   '홈팀 선발': '고영표',
#   '어웨이팀 선발': '스탁',
#   '구장': '구장 : 수원'},
#  {'날짜': '2022.07.02(토)',
#   '시작시간': '18:00',
#   '종료시간': '21:01',
#   '경기시간': '3:01',
#   '홈팀 선발': '벤자민',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 수원'},
#  {'날짜': '2022.07.03(일)',
#   '시작시간': '17:00',
#   '종료시간': '19:38',
#   '경기시간': '2:38',
#   '홈팀 선발': '소형준',
#   '어웨이팀 선발': '박신지',
#   '구장': '구장 : 수원'},
#  {'날짜': '2022.07.05(화)',
#   '시작시간': '18:31',
#   '종료시간': '21:54',
#   '경기시간': '3:23',
#   '홈팀 선발': '이영하',
#   '어웨이팀 선발': '안우진',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.07.06(수)',
#   '시작시간': '18:31',
#   '종료시간': '21:28',
#   '경기시간': '2:57',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '요키시',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.07.07(목)',
#   '시작시간': '18:30',
#   '종료시간': '21:56',
#   '경기시간': '3:26',
#   '홈팀 선발': '스탁',
#   '어웨이팀 선발': '애플러',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.07.08(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:50',
#   '경기시간': '3:20',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '플럿코',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.07.09(토)',
#   '시작시간': '18:00',
#   '종료시간': '22:11',
#   '경기시간': '4:11',
#   '홈팀 선발': '박신지',
#   '어웨이팀 선발': '임찬규',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.07.10(일)',
#   '시작시간': '17:01',
#   '종료시간': '20:22',
#   '경기시간': '3:21',
#   '홈팀 선발': '이영하',
#   '어웨이팀 선발': '켈리',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.07.12(화)',
#   '시작시간': '18:30',
#   '종료시간': '22:42',
#   '경기시간': '4:12',
#   '홈팀 선발': '신민혁',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 창원'},
#  {'날짜': '2022.07.13(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:30',
#   '경기시간': '3:00',
#   '홈팀 선발': '이재학',
#   '어웨이팀 선발': '스탁',
#   '구장': '구장 : 창원'},
#  {'날짜': '2022.07.14(목)',
#   '시작시간': '18:30',
#   '종료시간': '21:35',
#   '경기시간': '3:05',
#   '홈팀 선발': '루친스키',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 창원'},
#  {'날짜': '2022.07.22(금)',
#   '시작시간': '18:30',
#   '종료시간': '22:09',
#   '경기시간': '3:39',
#   '홈팀 선발': '스탁',
#   '어웨이팀 선발': '김광현',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.07.24(일)',
#   '시작시간': '17:00',
#   '종료시간': '20:20',
#   '경기시간': '3:20',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '폰트',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.07.26(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:19',
#   '경기시간': '2:49',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '김진욱',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.07.27(수)',
#   '시작시간': '18:31',
#   '종료시간': '22:16',
#   '경기시간': '3:45',
#   '홈팀 선발': '이영하',
#   '어웨이팀 선발': '이인복',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.07.28(목)',
#   '시작시간': '18:30',
#   '종료시간': '21:45',
#   '경기시간': '3:15',
#   '홈팀 선발': '스탁',
#   '어웨이팀 선발': '반즈',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.07.29(금)',
#   '시작시간': '18:29',
#   '종료시간': '22:25',
#   '경기시간': '3:56',
#   '홈팀 선발': '김민우',
#   '어웨이팀 선발': '최승용',
#   '구장': '구장 : 대전'},
#  {'날짜': '2022.07.30(토)',
#   '시작시간': '18:00',
#   '종료시간': '21:15',
#   '경기시간': '3:15',
#   '홈팀 선발': '페냐',
#   '어웨이팀 선발': '박신지',
#   '구장': '구장 : 대전'},
#  {'날짜': '2022.08.03(수)',
#   '시작시간': '18:30',
#   '종료시간': '22:08',
#   '경기시간': '3:38',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '수아레즈',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.08.04(목)',
#   '시작시간': '18:31',
#   '종료시간': '21:50',
#   '경기시간': '3:19',
#   '홈팀 선발': '이영하',
#   '어웨이팀 선발': '원태인',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.08.05(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:42',
#   '경기시간': '3:12',
#   '홈팀 선발': '이의리',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 광주'},
#  {'날짜': '2022.08.06(토)',
#   '시작시간': '18:00',
#   '종료시간': '21:49',
#   '경기시간': '3:49',
#   '홈팀 선발': '임기영',
#   '어웨이팀 선발': '스탁',
#   '구장': '구장 : 광주'},
#  {'날짜': '2022.08.07(일)',
#   '시작시간': '17:00',
#   '종료시간': '20:24',
#   '경기시간': '3:24',
#   '홈팀 선발': '놀린',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 광주'},
#  {'날짜': '2022.08.10(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:41',
#   '경기시간': '3:11',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '이재학',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.08.11(목)',
#   '시작시간': '18:30',
#   '종료시간': '22:03',
#   '경기시간': '3:33',
#   '홈팀 선발': '브랜든',
#   '어웨이팀 선발': '신민혁',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.08.12(금)',
#   '시작시간': '18:31',
#   '종료시간': '21:52',
#   '경기시간': '3:21',
#   '홈팀 선발': '스탁',
#   '어웨이팀 선발': '루친스키',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.08.13(토)',
#   '시작시간': '18:01',
#   '종료시간': '21:47',
#   '경기시간': '3:46',
#   '홈팀 선발': '이영하',
#   '어웨이팀 선발': '박종훈',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.08.14(일)',
#   '시작시간': '17:01',
#   '종료시간': '21:17',
#   '경기시간': '3:46',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '모리만도',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.08.17(수)',
#   '시작시간': '18:31',
#   '종료시간': '21:39',
#   '경기시간': '3:08',
#   '홈팀 선발': '반즈',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 사직'},
#  {'날짜': '2022.08.18(목)',
#   '시작시간': '18:29',
#   '종료시간': '21:30',
#   '경기시간': '3:01',
#   '홈팀 선발': '브랜든',
#   '어웨이팀 선발': '최원태',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.08.20(토)',
#   '시작시간': '18:00',
#   '종료시간': '21:21',
#   '경기시간': '3:21',
#   '홈팀 선발': '켈리',
#   '어웨이팀 선발': '스탁',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.08.21(일)',
#   '시작시간': '17:00',
#   '종료시간': '20:26',
#   '경기시간': '3:26',
#   '홈팀 선발': '임찬규',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.08.23(화)',
#   '시작시간': '18:30',
#   '종료시간': '22:30',
#   '경기시간': '4:00',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '벤자민',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.08.24(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:44',
#   '경기시간': '3:14',
#   '홈팀 선발': '브랜든',
#   '어웨이팀 선발': '고영표',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.08.25(목)',
#   '시작시간': '18:29',
#   '종료시간': '21:56',
#   '경기시간': '3:27',
#   '홈팀 선발': '장민재',
#   '어웨이팀 선발': '최승용',
#   '구장': '구장 : 대전'},
#  {'날짜': '2022.08.26(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:28',
#   '경기시간': '2:58',
#   '홈팀 선발': '페냐',
#   '어웨이팀 선발': '스탁',
#   '구장': '구장 : 대전'},
#  {'날짜': '2022.08.27(토)',
#   '시작시간': '18:01',
#   '종료시간': '21:00',
#   '경기시간': '2:59',
#   '홈팀 선발': '임기영',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 광주'},
#  {'날짜': '2022.08.28(일)',
#   '시작시간': '17:01',
#   '종료시간': '20:48',
#   '경기시간': '3:47',
#   '홈팀 선발': '파노니',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 광주'},
#  {'날짜': '2022.08.31(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:19',
#   '경기시간': '2:49',
#   '홈팀 선발': '고영표',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 수원'},
#  {'날짜': '2022.09.01(목)',
#   '시작시간': '18:29',
#   '종료시간': '21:15',
#   '경기시간': '2:46',
#   '홈팀 선발': '스탁',
#   '어웨이팀 선발': '나균안',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.09.02(금)',
#   '시작시간': '18:30',
#   '종료시간': '22:23',
#   '경기시간': '3:53',
#   '홈팀 선발': '박신지',
#   '어웨이팀 선발': '스트레일리',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.09.03(토)',
#   '시작시간': '16:59',
#   '종료시간': '20:12',
#   '경기시간': '3:13',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '백정현',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.09.06(화)',
#   '시작시간': '18:31',
#   '종료시간': '21:14',
#   '경기시간': '2:43',
#   '홈팀 선발': '루친스키',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 창원'},
#  {'날짜': '2022.09.07(수)',
#   '시작시간': '18:30',
#   '종료시간': '22:06',
#   '경기시간': '3:36',
#   '홈팀 선발': '송명기',
#   '어웨이팀 선발': '스탁',
#   '구장': '구장 : 창원'},
#  {'날짜': '2022.09.08(목)',
#   '시작시간': '18:31',
#   '종료시간': '22:07',
#   '경기시간': '3:36',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '페냐',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.09.09(금)',
#   '시작시간': '14:00',
#   '종료시간': '17:14',
#   '경기시간': '3:14',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '남지민',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.09.10(토)',
#   '시작시간': '13:59',
#   '종료시간': '16:36',
#   '경기시간': '2:37',
#   '홈팀 선발': '최승용',
#   '어웨이팀 선발': '임기영',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.09.11(일)',
#   '시작시간': '14:01',
#   '종료시간': '17:24',
#   '경기시간': '3:23',
#   '홈팀 선발': '브랜든',
#   '어웨이팀 선발': '양현종',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.09.13(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:35',
#   '경기시간': '3:05',
#   '홈팀 선발': '박신지',
#   '어웨이팀 선발': '켈리',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.09.14(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:46',
#   '경기시간': '3:16',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '임찬규',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.09.15(목)',
#   '시작시간': '18:30',
#   '종료시간': '22:07',
#   '경기시간': '3:37',
#   '홈팀 선발': '백정현',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 대구'},
#  {'날짜': '2022.09.16(금)',
#   '시작시간': '18:30',
#   '종료시간': '22:28',
#   '경기시간': '3:58',
#   '홈팀 선발': '허윤동',
#   '어웨이팀 선발': '최승용',
#   '구장': '구장 : 대구'},
#  {'날짜': '2022.09.17(토)',
#   '시작시간': '17:00',
#   '종료시간': '19:47',
#   '경기시간': '2:47',
#   '홈팀 선발': '김광현',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 문학'},
#  {'날짜': '2022.09.18(일)',
#   '시작시간': '13:59',
#   '종료시간': '18:14',
#   '경기시간': '4:15',
#   '홈팀 선발': '폰트',
#   '어웨이팀 선발': '스탁',
#   '구장': '구장 : 문학'},
#  {'날짜': '2022.09.20(화)',
#   '시작시간': '18:30',
#   '종료시간': '22:02',
#   '경기시간': '3:32',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '더모디',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.09.21(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:53',
#   '경기시간': '3:23',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '송명기',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.09.22(목)',
#   '시작시간': '18:30',
#   '종료시간': '22:12',
#   '경기시간': '3:42',
#   '홈팀 선발': '정찬헌',
#   '어웨이팀 선발': '최승용',
#   '구장': '구장 : 고척'},
#  {'날짜': '2022.09.23(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:46',
#   '경기시간': '3:16',
#   '홈팀 선발': '애플러',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 고척'},
#  {'날짜': '2022.09.24(토)',
#   '시작시간': '16:59',
#   '종료시간': '20:10',
#   '경기시간': '3:11',
#   '홈팀 선발': '이태양',
#   '어웨이팀 선발': '박신지',
#   '구장': '구장 : 문학'},
#  {'날짜': '2022.09.25(일)',
#   '시작시간': '14:00',
#   '종료시간': '17:07',
#   '경기시간': '3:07',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '한승주',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.09.27(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:29',
#   '경기시간': '2:59',
#   '홈팀 선발': '벤자민',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 수원'},
#  {'날짜': '2022.09.28(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:22',
#   '경기시간': '2:52',
#   '홈팀 선발': '소형준',
#   '어웨이팀 선발': '최승용',
#   '구장': '구장 : 수원'},
#  {'날짜': '2022.09.29(목)',
#   '시작시간': '18:30',
#   '종료시간': '22:05',
#   '경기시간': '3:35',
#   '홈팀 선발': '김기중',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 대전'},
#  {'날짜': '2022.09.30(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:57',
#   '경기시간': '3:27',
#   '홈팀 선발': '백정현',
#   '어웨이팀 선발': '스탁',
#   '구장': '구장 : 대구'},
#  {'날짜': '2022.10.01(토)',
#   '시작시간': '17:01',
#   '종료시간': '19:43',
#   '경기시간': '2:42',
#   '홈팀 선발': '수아레즈',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 대구'},
#  {'날짜': '2022.10.02(일)',
#   '시작시간': '14:00',
#   '종료시간': '17:13',
#   '경기시간': '3:13',
#   '홈팀 선발': '박세웅',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 사직'},
#  {'날짜': '2022.10.03(월)',
#   '시작시간': '14:00',
#   '종료시간': '17:47',
#   '경기시간': '3:47',
#   '홈팀 선발': '나균안',
#   '어웨이팀 선발': '최승용',
#   '구장': '구장 : 사직'},
#  {'날짜': '2022.10.05(수)',
#   '시작시간': '18:31',
#   '종료시간': '21:16',
#   '경기시간': '2:45',
#   '홈팀 선발': '브랜든',
#   '어웨이팀 선발': '김광현',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.10.06(목)',
#   '시작시간': '18:31',
#   '종료시간': '21:18',
#   '경기시간': '2:47',
#   '홈팀 선발': '스탁',
#   '어웨이팀 선발': '백정현',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.10.07(금)',
#   '시작시간': '18:31',
#   '종료시간': '22:01',
#   '경기시간': '3:30',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '김윤수',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2022.10.08(토)',
#   '시작시간': '17:01',
#   '종료시간': '19:54',
#   '경기시간': '2:53',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '안우진',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.04.01(토)',
#   '시작시간': '14:02',
#   '종료시간': '18:45',
#   '경기시간': '4:43',
#   '홈팀 선발': '알칸타라',
#   '어웨이팀 선발': '스트레일리',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.04.02(일)',
#   '시작시간': '14:00',
#   '종료시간': '17:00',
#   '경기시간': '3:00',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '나균안',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.04.04(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:13',
#   '경기시간': '2:43',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '송명기',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.04.05(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:57',
#   '경기시간': '3:27',
#   '홈팀 선발': '최승용',
#   '어웨이팀 선발': '신민혁',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.04.06(목)',
#   '시작시간': '18:30',
#   '종료시간': '22:05',
#   '경기시간': '3:35',
#   '홈팀 선발': '김동주',
#   '어웨이팀 선발': '이준호',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.04.07(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:38',
#   '경기시간': '3:08',
#   '홈팀 선발': '앤더슨',
#   '어웨이팀 선발': '알칸타라',
#   '구장': '구장 : 광주'},
#  {'날짜': '2023.04.08(토)',
#   '시작시간': '17:01',
#   '종료시간': '21:01',
#   '경기시간': '4:00',
#   '홈팀 선발': '이의리',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 광주'},
#  {'날짜': '2023.04.09(일)',
#   '시작시간': '14:00',
#   '종료시간': '17:15',
#   '경기시간': '3:15',
#   '홈팀 선발': '메디나',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 광주'},
#  {'날짜': '2023.04.11(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:46',
#   '경기시간': '3:16',
#   '홈팀 선발': '최승용',
#   '어웨이팀 선발': '최원태',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.04.13(목)',
#   '시작시간': '18:31',
#   '종료시간': '22:06',
#   '경기시간': '3:35',
#   '홈팀 선발': '김동주',
#   '어웨이팀 선발': '안우진',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.04.14(금)',
#   '시작시간': '18:30',
#   '종료시간': '22:01',
#   '경기시간': '3:31',
#   '홈팀 선발': '김윤식',
#   '어웨이팀 선발': '알칸타라',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.04.15(토)',
#   '시작시간': '17:00',
#   '종료시간': '19:32',
#   '경기시간': '2:32',
#   '홈팀 선발': '플럿코',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.04.16(일)',
#   '시작시간': '14:00',
#   '종료시간': '17:24',
#   '경기시간': '3:24',
#   '홈팀 선발': '임찬규',
#   '어웨이팀 선발': '최승용',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.04.18(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:28',
#   '경기시간': '2:58',
#   '홈팀 선발': '문동주',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 대전'},
#  {'날짜': '2023.04.19(수)',
#   '시작시간': '18:30',
#   '종료시간': '22:04',
#   '경기시간': '3:34',
#   '홈팀 선발': '장민재',
#   '어웨이팀 선발': '김동주',
#   '구장': '구장 : 대전'},
#  {'날짜': '2023.04.20(목)',
#   '시작시간': '18:30',
#   '종료시간': '21:27',
#   '경기시간': '2:57',
#   '홈팀 선발': '김민우',
#   '어웨이팀 선발': '알칸타라',
#   '구장': '구장 : 대전'},
#  {'날짜': '2023.04.21(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:50',
#   '경기시간': '3:20',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '배제성',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.04.22(토)',
#   '시작시간': '17:00',
#   '종료시간': '19:46',
#   '경기시간': '2:46',
#   '홈팀 선발': '최승용',
#   '어웨이팀 선발': '슐서',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.04.23(일)',
#   '시작시간': '14:00',
#   '종료시간': '17:31',
#   '경기시간': '3:31',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '고영표',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.04.26(수)',
#   '시작시간': '18:29',
#   '종료시간': '21:28',
#   '경기시간': '2:59',
#   '홈팀 선발': '뷰캐넌',
#   '어웨이팀 선발': '알칸타라',
#   '구장': '구장 : 대구'},
#  {'날짜': '2023.04.27(목)',
#   '시작시간': '18:29',
#   '종료시간': '21:09',
#   '경기시간': '2:40',
#   '홈팀 선발': '장필준',
#   '어웨이팀 선발': '김동주',
#   '구장': '구장 : 대구'},
#  {'날짜': '2023.04.28(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:35',
#   '경기시간': '3:05',
#   '홈팀 선발': '맥카티',
#   '어웨이팀 선발': '최승용',
#   '구장': '구장 : 문학'},
#  {'날짜': '2023.04.29(토)',
#   '시작시간': '16:59',
#   '종료시간': '20:39',
#   '경기시간': '3:40',
#   '홈팀 선발': '오원석',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 문학'},
#  {'날짜': '2023.04.30(일)',
#   '시작시간': '13:59',
#   '종료시간': '16:41',
#   '경기시간': '2:42',
#   '홈팀 선발': '박종훈',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 문학'},
#  {'날짜': '2023.05.02(화)',
#   '시작시간': '18:31',
#   '종료시간': '21:36',
#   '경기시간': '3:05',
#   '홈팀 선발': '알칸타라',
#   '어웨이팀 선발': '장민재',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.05.03(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:57',
#   '경기시간': '3:27',
#   '홈팀 선발': '김동주',
#   '어웨이팀 선발': '김민우',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.05.04(목)',
#   '시작시간': '18:30',
#   '종료시간': '22:08',
#   '경기시간': '3:38',
#   '홈팀 선발': '딜런',
#   '어웨이팀 선발': '페냐',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.05.07(일)',
#   '시작시간': '13:59',
#   '종료시간': '16:51',
#   '경기시간': '2:52',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '켈리',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.05.09(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:15',
#   '경기시간': '2:45',
#   '홈팀 선발': '스트레일리',
#   '어웨이팀 선발': '알칸타라',
#   '구장': '구장 : 사직'},
#  {'날짜': '2023.05.10(수)',
#   '시작시간': '18:30',
#   '종료시간': '20:52',
#   '경기시간': '2:22',
#   '홈팀 선발': '반즈',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 사직'},
#  {'날짜': '2023.05.11(목)',
#   '시작시간': '18:31',
#   '종료시간': '22:32',
#   '경기시간': '4:01',
#   '홈팀 선발': '나균안',
#   '어웨이팀 선발': '딜런',
#   '구장': '구장 : 사직'},
#  {'날짜': '2023.05.12(금)',
#   '시작시간': '18:31',
#   '종료시간': '21:58',
#   '경기시간': '3:27',
#   '홈팀 선발': '김동주',
#   '어웨이팀 선발': '이의리',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.05.13(토)',
#   '시작시간': '17:01',
#   '종료시간': '19:31',
#   '경기시간': '2:30',
#   '홈팀 선발': '최승용',
#   '어웨이팀 선발': '메디나',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.05.14(일)',
#   '시작시간': '14:00',
#   '종료시간': '17:33',
#   '경기시간': '3:33',
#   '홈팀 선발': '알칸타라',
#   '어웨이팀 선발': '양현종',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.05.16(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:48',
#   '경기시간': '3:18',
#   '홈팀 선발': '최원태',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 고척'},
#  {'날짜': '2023.05.17(수)',
#   '시작시간': '18:30',
#   '종료시간': '22:14',
#   '경기시간': '3:44',
#   '홈팀 선발': '정찬헌',
#   '어웨이팀 선발': '이원재',
#   '구장': '구장 : 고척'},
#  {'날짜': '2023.05.18(목)',
#   '시작시간': '18:30',
#   '종료시간': '22:09',
#   '경기시간': '3:39',
#   '홈팀 선발': '안우진',
#   '어웨이팀 선발': '김동주',
#   '구장': '구장 : 고척'},
#  {'날짜': '2023.05.19(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:40',
#   '경기시간': '3:10',
#   '홈팀 선발': '엄상백',
#   '어웨이팀 선발': '최승용',
#   '구장': '구장 : 수원'},
#  {'날짜': '2023.05.20(토)',
#   '시작시간': '17:00',
#   '종료시간': '19:44',
#   '경기시간': '2:44',
#   '홈팀 선발': '배제성',
#   '어웨이팀 선발': '알칸타라',
#   '구장': '구장 : 수원'},
#  {'날짜': '2023.05.21(일)',
#   '시작시간': '13:59',
#   '종료시간': '16:43',
#   '경기시간': '2:44',
#   '홈팀 선발': '벤자민',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 수원'},
#  {'날짜': '2023.05.23(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:49',
#   '경기시간': '3:19',
#   '홈팀 선발': '장원준',
#   '어웨이팀 선발': '원태인',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.05.24(수)',
#   '시작시간': '18:31',
#   '종료시간': '22:06',
#   '경기시간': '3:35',
#   '홈팀 선발': '김동주',
#   '어웨이팀 선발': '수아레즈',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.05.25(목)',
#   '시작시간': '18:31',
#   '종료시간': '22:12',
#   '경기시간': '3:41',
#   '홈팀 선발': '최승용',
#   '어웨이팀 선발': '백정현',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.05.26(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:50',
#   '경기시간': '3:20',
#   '홈팀 선발': '알칸타라',
#   '어웨이팀 선발': '박종훈',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.05.30(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:27',
#   '경기시간': '2:57',
#   '홈팀 선발': '와이드너',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 창원'},
#  {'날짜': '2023.05.31(수)',
#   '시작시간': '18:31',
#   '종료시간': '22:16',
#   '경기시간': '3:45',
#   '홈팀 선발': '이용준',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 창원'},
#  {'날짜': '2023.06.02(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:25',
#   '경기시간': '2:55',
#   '홈팀 선발': '배제성',
#   '어웨이팀 선발': '알칸타라',
#   '구장': '구장 : 수원'},
#  {'날짜': '2023.06.03(토)',
#   '시작시간': '17:00',
#   '종료시간': '20:24',
#   '경기시간': '3:24',
#   '홈팀 선발': '벤자민',
#   '어웨이팀 선발': '김동주',
#   '구장': '구장 : 수원'},
#  {'날짜': '2023.06.04(일)',
#   '시작시간': '17:00',
#   '종료시간': '20:12',
#   '경기시간': '3:12',
#   '홈팀 선발': '이선우',
#   '어웨이팀 선발': '최승용',
#   '구장': '구장 : 수원'},
#  {'날짜': '2023.06.06(화)',
#   '시작시간': '14:01',
#   '종료시간': '17:12',
#   '경기시간': '3:11',
#   '홈팀 선발': '장원준',
#   '어웨이팀 선발': '장민재',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.06.07(수)',
#   '시작시간': '18:31',
#   '종료시간': '21:54',
#   '경기시간': '3:23',
#   '홈팀 선발': '박신지',
#   '어웨이팀 선발': '문동주',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.06.08(목)',
#   '시작시간': '18:31',
#   '종료시간': '21:11',
#   '경기시간': '2:40',
#   '홈팀 선발': '알칸타라',
#   '어웨이팀 선발': '김민우',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.06.09(금)',
#   '시작시간': '18:30',
#   '종료시간': '22:37',
#   '경기시간': '4:07',
#   '홈팀 선발': '김동주',
#   '어웨이팀 선발': '메디나',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.06.10(토)',
#   '시작시간': '17:00',
#   '종료시간': '20:26',
#   '경기시간': '3:26',
#   '홈팀 선발': '최승용',
#   '어웨이팀 선발': '이의리',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.06.11(일)',
#   '시작시간': '16:58',
#   '종료시간': '19:31',
#   '경기시간': '2:33',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '윤영철',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.06.13(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:45',
#   '경기시간': '3:15',
#   '홈팀 선발': '이용준',
#   '어웨이팀 선발': '장원준',
#   '구장': '구장 : 창원'},
#  {'날짜': '2023.06.14(수)',
#   '시작시간': '18:30',
#   '종료시간': '23:27',
#   '경기시간': '3:39',
#   '홈팀 선발': '최성영',
#   '어웨이팀 선발': '알칸타라',
#   '구장': '구장 : 창원'},
#  {'날짜': '2023.06.15(목)',
#   '시작시간': '18:31',
#   '종료시간': '22:04',
#   '경기시간': '3:33',
#   '홈팀 선발': '신민혁',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 창원'},
#  {'날짜': '2023.06.16(금)',
#   '시작시간': '18:30',
#   '종료시간': '22:12',
#   '경기시간': '3:42',
#   '홈팀 선발': '이민호',
#   '어웨이팀 선발': '최승용',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.06.17(토)',
#   '시작시간': '17:00',
#   '종료시간': '20:08',
#   '경기시간': '3:08',
#   '홈팀 선발': '켈리',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.06.18(일)',
#   '시작시간': '17:00',
#   '종료시간': '20:04',
#   '경기시간': '3:04',
#   '홈팀 선발': '플럿코',
#   '어웨이팀 선발': '장원준',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.06.20(화)',
#   '시작시간': '18:31',
#   '종료시간': '22:05',
#   '경기시간': '3:34',
#   '홈팀 선발': '알칸타라',
#   '어웨이팀 선발': '조성훈',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.06.21(수)',
#   '시작시간': '18:30',
#   '종료시간': '22:14',
#   '경기시간': '3:44',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '오원석',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.06.22(목)',
#   '시작시간': '18:31',
#   '종료시간': '21:57',
#   '경기시간': '3:20',
#   '홈팀 선발': '최승용',
#   '어웨이팀 선발': '맥카티',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.06.23(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:53',
#   '경기시간': '3:23',
#   '홈팀 선발': '장재영',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 고척'},
#  {'날짜': '2023.06.24(토)',
#   '시작시간': '17:00',
#   '종료시간': '19:39',
#   '경기시간': '2:39',
#   '홈팀 선발': '후라도',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 고척'},
#  {'날짜': '2023.06.25(일)',
#   '시작시간': '14:00',
#   '종료시간': '17:40',
#   '경기시간': '3:40',
#   '홈팀 선발': '맥키니',
#   '어웨이팀 선발': '알칸타라',
#   '구장': '구장 : 고척'},
#  {'날짜': '2023.06.27(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:12',
#   '경기시간': '2:42',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '신민혁',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.06.28(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:43',
#   '경기시간': '3:13',
#   '홈팀 선발': '장원준',
#   '어웨이팀 선발': '페디',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.06.30(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:57',
#   '경기시간': '3:27',
#   '홈팀 선발': '박세웅',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 울산'},
#  {'날짜': '2023.07.01(토)',
#   '시작시간': '18:01',
#   '종료시간': '21:04',
#   '경기시간': '3:03',
#   '홈팀 선발': '반즈',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 울산'},
#  {'날짜': '2023.07.02(일)',
#   '시작시간': '17:00',
#   '종료시간': '20:11',
#   '경기시간': '3:11',
#   '홈팀 선발': '스트레일리',
#   '어웨이팀 선발': '알칸타라',
#   '구장': '구장 : 울산'},
#  {'날짜': '2023.07.04(화)',
#   '시작시간': '18:30',
#   '종료시간': '22:54',
#   '경기시간': '4:24',
#   '홈팀 선발': '수아레즈',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 포항'},
#  {'날짜': '2023.07.05(수)',
#   '시작시간': '18:29',
#   '종료시간': '22:04',
#   '경기시간': '3:35',
#   '홈팀 선발': '황동재',
#   '어웨이팀 선발': '김동주',
#   '구장': '구장 : 포항'},
#  {'날짜': '2023.07.06(목)',
#   '시작시간': '18:28',
#   '종료시간': '21:19',
#   '경기시간': '2:51',
#   '홈팀 선발': '최채흥',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 포항'},
#  {'날짜': '2023.07.07(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:59',
#   '경기시간': '3:29',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '맥키니',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.07.08(토)',
#   '시작시간': '18:01',
#   '종료시간': '21:06',
#   '경기시간': '3:05',
#   '홈팀 선발': '알칸타라',
#   '어웨이팀 선발': '최원태',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.07.09(일)',
#   '시작시간': '17:00',
#   '종료시간': '20:15',
#   '경기시간': '3:15',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '정찬헌',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.07.12(수)',
#   '시작시간': '18:29',
#   '종료시간': '21:52',
#   '경기시간': '3:23',
#   '홈팀 선발': '김광현',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 문학'},
#  {'날짜': '2023.07.21(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:30',
#   '경기시간': '3:00',
#   '홈팀 선발': '산체스',
#   '어웨이팀 선발': '알칸타라',
#   '구장': '구장 : 광주'},
#  {'날짜': '2023.07.25(화)',
#   '시작시간': '18:30',
#   '종료시간': '22:10',
#   '경기시간': '3:32',
#   '홈팀 선발': '브랜든',
#   '어웨이팀 선발': '나균안',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.07.26(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:47',
#   '경기시간': '3:17',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '윌커슨',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.07.27(목)',
#   '시작시간': '18:30',
#   '종료시간': '21:46',
#   '경기시간': '3:16',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '반즈',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.07.28(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:42',
#   '경기시간': '3:12',
#   '홈팀 선발': '알칸타라',
#   '어웨이팀 선발': '켈리',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.07.29(토)',
#   '시작시간': '18:00',
#   '종료시간': '22:15',
#   '경기시간': '4:15',
#   '홈팀 선발': '김동주',
#   '어웨이팀 선발': '이지강',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.07.30(일)',
#   '시작시간': '17:00',
#   '종료시간': '19:54',
#   '경기시간': '2:54',
#   '홈팀 선발': '브랜든',
#   '어웨이팀 선발': '최원태',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.08.01(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:37',
#   '경기시간': '3:07',
#   '홈팀 선발': '문동주',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 대전'},
#  {'날짜': '2023.08.02(수)',
#   '시작시간': '18:30',
#   '종료시간': '22:34',
#   '경기시간': '4:04',
#   '홈팀 선발': '산체스',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 대전'},
#  {'날짜': '2023.08.03(목)',
#   '시작시간': '18:30',
#   '종료시간': '21:40',
#   '경기시간': '3:10',
#   '홈팀 선발': '페냐',
#   '어웨이팀 선발': '알칸타라',
#   '구장': '구장 : 대전'},
#  {'날짜': '2023.08.04(금)',
#   '시작시간': '18:31',
#   '종료시간': '22:12',
#   '경기시간': '3:41',
#   '홈팀 선발': '김동주',
#   '어웨이팀 선발': '배제성',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.08.05(토)',
#   '시작시간': '18:01',
#   '종료시간': '21:01',
#   '경기시간': '3:00',
#   '홈팀 선발': '브랜든',
#   '어웨이팀 선발': '벤자민',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.08.06(일)',
#   '시작시간': '17:00',
#   '종료시간': '19:53',
#   '경기시간': '2:53',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '고영표',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.08.08(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:34',
#   '경기시간': '3:04',
#   '홈팀 선발': '최승용',
#   '어웨이팀 선발': '최채흥',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.08.09(수)',
#   '시작시간': '18:31',
#   '종료시간': '21:44',
#   '경기시간': '3:13',
#   '홈팀 선발': '알칸타라',
#   '어웨이팀 선발': '원태인',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.08.11(금)',
#   '시작시간': '18:30',
#   '종료시간': '22:07',
#   '경기시간': '3:37',
#   '홈팀 선발': '한승혁',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 대전'},
#  {'날짜': '2023.08.12(토)',
#   '시작시간': '18:01',
#   '종료시간': '21:01',
#   '경기시간': '3:00',
#   '홈팀 선발': '문동주',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 대전'},
#  {'날짜': '2023.08.13(일)',
#   '시작시간': '17:00',
#   '종료시간': '20:23',
#   '경기시간': '3:23',
#   '홈팀 선발': '산체스',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 대전'},
#  {'날짜': '2023.08.15(화)',
#   '시작시간': '17:01',
#   '종료시간': '19:38',
#   '경기시간': '2:37',
#   '홈팀 선발': '알칸타라',
#   '어웨이팀 선발': '쿠에바스',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.08.16(수)',
#   '시작시간': '18:31',
#   '종료시간': '21:54',
#   '경기시간': '3:23',
#   '홈팀 선발': '김동주',
#   '어웨이팀 선발': '엄상백',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.08.17(목)',
#   '시작시간': '18:31',
#   '종료시간': '22:28',
#   '경기시간': '3:57',
#   '홈팀 선발': '브랜든',
#   '어웨이팀 선발': '벤자민',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.08.19(토)',
#   '시작시간': '17:59',
#   '종료시간': '21:29',
#   '경기시간': '3:30',
#   '홈팀 선발': '최승용',
#   '어웨이팀 선발': '페디',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.08.20(일)',
#   '시작시간': '17:00',
#   '종료시간': '21:13',
#   '경기시간': '4:13',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '태너',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.08.22(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:17',
#   '경기시간': '2:47',
#   '홈팀 선발': '김선기',
#   '어웨이팀 선발': '알칸타라',
#   '구장': '구장 : 고척'},
#  {'날짜': '2023.08.23(수)',
#   '시작시간': '18:30',
#   '종료시간': '22:28',
#   '경기시간': '3:58',
#   '홈팀 선발': '장재영',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 고척'},
#  {'날짜': '2023.08.24(목)',
#   '시작시간': '18:30',
#   '종료시간': '22:37',
#   '경기시간': '4:07',
#   '홈팀 선발': '맥키니',
#   '어웨이팀 선발': '김동주',
#   '구장': '구장 : 고척'},
#  {'날짜': '2023.08.25(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:12',
#   '경기시간': '2:42',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '김광현',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.08.26(토)',
#   '시작시간': '18:00',
#   '종료시간': '21:57',
#   '경기시간': '3:57',
#   '홈팀 선발': '김민규',
#   '어웨이팀 선발': '엘리아스',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.08.27(일)',
#   '시작시간': '17:00',
#   '종료시간': '21:23',
#   '경기시간': '4:23',
#   '홈팀 선발': '알칸타라',
#   '어웨이팀 선발': '문승원',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.08.31(목)',
#   '시작시간': '18:30',
#   '종료시간': '22:05',
#   '경기시간': '3:35',
#   '홈팀 선발': '켈리',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.09.03(일)',
#   '시작시간': '14:00',
#   '종료시간': '16:41',
#   '경기시간': '2:41',
#   '홈팀 선발': '반즈',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 사직'},
#  {'날짜': '2023.09.04(월)',
#   '시작시간': '18:29',
#   '종료시간': '22:03',
#   '경기시간': '3:34',
#   '홈팀 선발': '박세웅',
#   '어웨이팀 선발': '알칸타라',
#   '구장': '구장 : 사직'},
#  {'날짜': '2023.09.06(수)',
#   '시작시간': '18:31',
#   '종료시간': '21:46',
#   '경기시간': '3:15',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '파노니',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.09.07(목)',
#   '시작시간': '18:30',
#   '종료시간': '21:32',
#   '경기시간': '3:02',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '양현종',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.09.08(금)',
#   '시작시간': '18:30',
#   '종료시간': '22:32',
#   '경기시간': '4:02',
#   '홈팀 선발': '최승용',
#   '어웨이팀 선발': '김대우',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.09.09(토)',
#   '시작시간': '14:01',
#   '종료시간': '16:47',
#   '경기시간': '2:46',
#   '홈팀 선발': '장원준',
#   '어웨이팀 선발': '뷰캐넌',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.09.09(토)',
#   '시작시간': '17:17',
#   '종료시간': '20:20',
#   '경기시간': '3:03',
#   '홈팀 선발': '브랜든',
#   '어웨이팀 선발': '최하늘',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.09.10(일)',
#   '시작시간': '14:00',
#   '종료시간': '17:23',
#   '경기시간': '3:23',
#   '홈팀 선발': '알칸타라',
#   '어웨이팀 선발': '최채흥',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.09.12(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:40',
#   '경기시간': '3:10',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '이태양',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.09.14(목)',
#   '시작시간': '18:30',
#   '종료시간': '21:22',
#   '경기시간': '2:52',
#   '홈팀 선발': '최승용',
#   '어웨이팀 선발': '엘리아스',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.09.15(금)',
#   '시작시간': '18:30',
#   '종료시간': '22:39',
#   '경기시간': '4:09',
#   '홈팀 선발': '윤영철',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 광주'},
#  {'날짜': '2023.09.17(일)',
#   '시작시간': '14:01',
#   '종료시간': '17:26',
#   '경기시간': '3:25',
#   '홈팀 선발': '파노니',
#   '어웨이팀 선발': '알칸타라',
#   '구장': '구장 : 광주'},
#  {'날짜': '2023.09.18(월)',
#   '시작시간': '18:29',
#   '종료시간': '21:49',
#   '경기시간': '3:20',
#   '홈팀 선발': '황동하',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 광주'},
#  {'날짜': '2023.09.19(화)',
#   '시작시간': '18:29',
#   '종료시간': '21:32',
#   '경기시간': '3:03',
#   '홈팀 선발': '장원준',
#   '어웨이팀 선발': '페디',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.09.21(목)',
#   '시작시간': '18:45',
#   '종료시간': '21:47',
#   '경기시간': '3:02',
#   '홈팀 선발': '뷰캐넌',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 대구'},
#  {'날짜': '2023.09.22(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:25',
#   '경기시간': '2:55',
#   '홈팀 선발': '최채흥',
#   '어웨이팀 선발': '최승용',
#   '구장': '구장 : 대구'},
#  {'날짜': '2023.09.23(토)',
#   '시작시간': '17:00',
#   '종료시간': '20:06',
#   '경기시간': '3:06',
#   '홈팀 선발': '이재학',
#   '어웨이팀 선발': '알칸타라',
#   '구장': '구장 : 창원'},
#  {'날짜': '2023.09.24(일)',
#   '시작시간': '14:00',
#   '종료시간': '18:11',
#   '경기시간': '4:11',
#   '홈팀 선발': '신민혁',
#   '어웨이팀 선발': '장원준',
#   '구장': '구장 : 창원'},
#  {'날짜': '2023.09.27(수)',
#   '시작시간': '15:00',
#   '종료시간': '19:04',
#   '경기시간': '4:04',
#   '홈팀 선발': '김광현',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 문학'},
#  {'날짜': '2023.09.27(수)',
#   '시작시간': '19:34',
#   '종료시간': '22:34',
#   '경기시간': '3:00',
#   '홈팀 선발': '엘리아스',
#   '어웨이팀 선발': '최승용',
#   '구장': '구장 : 문학'},
#  {'날짜': '2023.09.29(금)',
#   '시작시간': '14:00',
#   '종료시간': '17:07',
#   '경기시간': '3:07',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '임찬규',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.09.30(토)',
#   '시작시간': '14:12',
#   '종료시간': '18:16',
#   '경기시간': '4:04',
#   '홈팀 선발': '김동주',
#   '어웨이팀 선발': '최원태',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.10.01(일)',
#   '시작시간': '14:01',
#   '종료시간': '16:59',
#   '경기시간': '2:58',
#   '홈팀 선발': '알칸타라',
#   '어웨이팀 선발': '이지강',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.10.02(월)',
#   '시작시간': '14:00',
#   '종료시간': '16:45',
#   '경기시간': '2:45',
#   '홈팀 선발': '브랜든',
#   '어웨이팀 선발': '장재영',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.10.03(화)',
#   '시작시간': '14:01',
#   '종료시간': '17:44',
#   '경기시간': '3:43',
#   '홈팀 선발': '최승용',
#   '어웨이팀 선발': '이종민',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.10.07(토)',
#   '시작시간': '17:00',
#   '종료시간': '20:21',
#   '경기시간': '3:21',
#   '홈팀 선발': '알칸타라',
#   '어웨이팀 선발': '윌커슨',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.10.08(일)',
#   '시작시간': '14:00',
#   '종료시간': '16:38',
#   '경기시간': '2:38',
#   '홈팀 선발': '브랜든',
#   '어웨이팀 선발': '반즈',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.10.10(화)',
#   '시작시간': '18:31',
#   '종료시간': '22:27',
#   '경기시간': '3:56',
#   '홈팀 선발': '조이현',
#   '어웨이팀 선발': '최승용',
#   '구장': '구장 : 수원'},
#  {'날짜': '2023.10.11(수)',
#   '시작시간': '18:31',
#   '종료시간': '21:51',
#   '경기시간': '3:20',
#   '홈팀 선발': '박세웅',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 사직'},
#  {'날짜': '2023.10.12(목)',
#   '시작시간': '18:31',
#   '종료시간': '21:29',
#   '경기시간': '2:58',
#   '홈팀 선발': '장원준',
#   '어웨이팀 선발': '이재학',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.10.13(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:17',
#   '경기시간': '2:47',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '김건국',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.10.14(토)',
#   '시작시간': '17:00',
#   '종료시간': '19:44',
#   '경기시간': '2:44',
#   '홈팀 선발': '김윤식',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.10.15(일)',
#   '시작시간': '14:00',
#   '종료시간': '17:04',
#   '경기시간': '3:04',
#   '홈팀 선발': '임찬규',
#   '어웨이팀 선발': '김동주',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.10.16(월)',
#   '시작시간': '18:31',
#   '종료시간': '21:18',
#   '경기시간': '2:47',
#   '홈팀 선발': '알칸타라',
#   '어웨이팀 선발': '엘리아스',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2023.10.17(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:09',
#   '경기시간': '2:39',
#   '홈팀 선발': '김광현',
#   '어웨이팀 선발': '장원준',
#   '구장': '구장 : 문학'},
#  {'날짜': '2024.03.23(토)',
#   '시작시간': '14:01',
#   '종료시간': '16:49',
#   '경기시간': '2:48',
#   '홈팀 선발': '하트',
#   '어웨이팀 선발': '알칸타라',
#   '구장': '구장 : 창원'},
#  {'날짜': '2024.03.24(일)',
#   '시작시간': '14:00',
#   '종료시간': '17:35',
#   '경기시간': '3:04',
#   '홈팀 선발': '신민혁',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 창원'},
#  {'날짜': '2024.03.26(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:28',
#   '경기시간': '2:58',
#   '홈팀 선발': '벤자민',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 수원'},
#  {'날짜': '2024.03.27(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:49',
#   '경기시간': '3:19',
#   '홈팀 선발': '고영표',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 수원'},
#  {'날짜': '2024.03.28(목)',
#   '시작시간': '18:30',
#   '종료시간': '22:01',
#   '경기시간': '3:31',
#   '홈팀 선발': '원상현',
#   '어웨이팀 선발': '김동주',
#   '구장': '구장 : 수원'},
#  {'날짜': '2024.03.29(금)',
#   '시작시간': '18:31',
#   '종료시간': '22:19',
#   '경기시간': '3:48',
#   '홈팀 선발': '알칸타라',
#   '어웨이팀 선발': '이의리',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.03.30(토)',
#   '시작시간': '17:02',
#   '종료시간': '19:51',
#   '경기시간': '2:49',
#   '홈팀 선발': '브랜든',
#   '어웨이팀 선발': '크로우',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.03.31(일)',
#   '시작시간': '14:01',
#   '종료시간': '17:08',
#   '경기시간': '3:07',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '윤영철',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.04.02(화)',
#   '시작시간': '18:29',
#   '종료시간': '22:03',
#   '경기시간': '3:34',
#   '홈팀 선발': '송영진',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 문학'},
#  {'날짜': '2024.04.03(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:33',
#   '경기시간': '3:03',
#   '홈팀 선발': '오원석',
#   '어웨이팀 선발': '김동주',
#   '구장': '구장 : 문학'},
#  {'날짜': '2024.04.04(목)',
#   '시작시간': '18:29',
#   '종료시간': '21:16',
#   '경기시간': '2:47',
#   '홈팀 선발': '김광현',
#   '어웨이팀 선발': '알칸타라',
#   '구장': '구장 : 문학'},
#  {'날짜': '2024.04.05(금)',
#   '시작시간': '18:29',
#   '종료시간': '21:46',
#   '경기시간': '3:17',
#   '홈팀 선발': '이인복',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 사직'},
#  {'날짜': '2024.04.06(토)',
#   '시작시간': '17:00',
#   '종료시간': '19:42',
#   '경기시간': '2:42',
#   '홈팀 선발': '박세웅',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 사직'},
#  {'날짜': '2024.04.07(일)',
#   '시작시간': '14:01',
#   '종료시간': '18:09',
#   '경기시간': '4:08',
#   '홈팀 선발': '반즈',
#   '어웨이팀 선발': '박신지',
#   '구장': '구장 : 사직'},
#  {'날짜': '2024.04.09(화)',
#   '시작시간': '18:31',
#   '종료시간': '21:33',
#   '경기시간': '3:02',
#   '홈팀 선발': '김동주',
#   '어웨이팀 선발': '산체스',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.04.10(수)',
#   '시작시간': '14:01',
#   '종료시간': '16:59',
#   '경기시간': '2:58',
#   '홈팀 선발': '알칸타라',
#   '어웨이팀 선발': '문동주',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.04.11(목)',
#   '시작시간': '18:31',
#   '종료시간': '21:15',
#   '경기시간': '2:44',
#   '홈팀 선발': '브랜든',
#   '어웨이팀 선발': '류현진',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.04.12(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:22',
#   '경기시간': '2:52',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '켈리',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.04.13(토)',
#   '시작시간': '17:01',
#   '종료시간': '20:20',
#   '경기시간': '3:19',
#   '홈팀 선발': '이영하',
#   '어웨이팀 선발': '최원태',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.04.14(일)',
#   '시작시간': '14:00',
#   '종료시간': '17:29',
#   '경기시간': '3:29',
#   '홈팀 선발': '김동주',
#   '어웨이팀 선발': '손주영',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.04.16(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:26',
#   '경기시간': '2:56',
#   '홈팀 선발': '코너',
#   '어웨이팀 선발': '박소준',
#   '구장': '구장 : 대구'},
#  {'날짜': '2024.04.17(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:34',
#   '경기시간': '3:04',
#   '홈팀 선발': '레예스',
#   '어웨이팀 선발': '김호준',
#   '구장': '구장 : 대구'},
#  {'날짜': '2024.04.18(목)',
#   '시작시간': '18:30',
#   '종료시간': '21:35',
#   '경기시간': '3:05',
#   '홈팀 선발': '이승현',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 대구'},
#  {'날짜': '2024.04.19(금)',
#   '시작시간': '18:30',
#   '종료시간': '22:09',
#   '경기시간': '3:39',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '김선기',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.04.21(일)',
#   '시작시간': '14:00',
#   '종료시간': '17:06',
#   '경기시간': '3:06',
#   '홈팀 선발': '김동주',
#   '어웨이팀 선발': '후라도',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.04.21(일)',
#   '시작시간': '17:47',
#   '종료시간': '20:19',
#   '경기시간': '2:32',
#   '홈팀 선발': '알칸타라',
#   '어웨이팀 선발': '김인범',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.04.23(화)',
#   '시작시간': '18:31',
#   '종료시간': '21:44',
#   '경기시간': '3:13',
#   '홈팀 선발': '최준호',
#   '어웨이팀 선발': '신민혁',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.04.24(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:25',
#   '경기시간': '2:55',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '이재학',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.04.25(목)',
#   '시작시간': '18:30',
#   '종료시간': '21:21',
#   '경기시간': '2:51',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '카스타노',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.04.26(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:39',
#   '경기시간': '3:09',
#   '홈팀 선발': '황준서',
#   '어웨이팀 선발': '김유성',
#   '구장': '구장 : 대전'},
#  {'날짜': '2024.04.27(토)',
#   '시작시간': '17:00',
#   '종료시간': '20:19',
#   '경기시간': '3:19',
#   '홈팀 선발': '산체스',
#   '어웨이팀 선발': '박정수',
#   '구장': '구장 : 대전'},
#  {'날짜': '2024.04.28(일)',
#   '시작시간': '14:00',
#   '종료시간': '17:56',
#   '경기시간': '3:56',
#   '홈팀 선발': '문동주',
#   '어웨이팀 선발': '최준호',
#   '구장': '구장 : 대전'},
#  {'날짜': '2024.04.30(화)',
#   '시작시간': '18:31',
#   '종료시간': '21:25',
#   '경기시간': '2:54',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '이승현',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.05.01(수)',
#   '시작시간': '18:31',
#   '종료시간': '21:22',
#   '경기시간': '2:51',
#   '홈팀 선발': '브랜든',
#   '어웨이팀 선발': '이호성',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.05.02(목)',
#   '시작시간': '18:30',
#   '종료시간': '21:16',
#   '경기시간': '2:46',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '원태인',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.05.03(금)',
#   '시작시간': '18:31',
#   '종료시간': '21:42',
#   '경기시간': '3:11',
#   '홈팀 선발': '엔스',
#   '어웨이팀 선발': '김유성',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.05.04(토)',
#   '시작시간': '14:01',
#   '종료시간': '17:00',
#   '경기시간': '2:59',
#   '홈팀 선발': '손주영',
#   '어웨이팀 선발': '최준호',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.05.07(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:16',
#   '경기시간': '2:46',
#   '홈팀 선발': '이종민',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 고척'},
#  {'날짜': '2024.05.08(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:19',
#   '경기시간': '2:49',
#   '홈팀 선발': '김인범',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 고척'},
#  {'날짜': '2024.05.09(목)',
#   '시작시간': '18:31',
#   '종료시간': '21:23',
#   '경기시간': '2:52',
#   '홈팀 선발': '후라도',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 고척'},
#  {'날짜': '2024.05.10(금)',
#   '시작시간': '18:31',
#   '종료시간': '21:54',
#   '경기시간': '3:23',
#   '홈팀 선발': '김유성',
#   '어웨이팀 선발': '원상현',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.05.12(일)',
#   '시작시간': '14:00',
#   '종료시간': '16:49',
#   '경기시간': '2:49',
#   '홈팀 선발': '최준호',
#   '어웨이팀 선발': '벤자민',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.05.12(일)',
#   '시작시간': '17:30',
#   '종료시간': '20:30',
#   '경기시간': '3:00',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '육청명',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.05.14(화)',
#   '시작시간': '18:29',
#   '종료시간': '21:39',
#   '경기시간': '3:10',
#   '홈팀 선발': '양현종',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 광주'},
#  {'날짜': '2024.05.15(수)',
#   '시작시간': '14:00',
#   '종료시간': '17:38',
#   '경기시간': '3:38',
#   '홈팀 선발': '네일',
#   '어웨이팀 선발': '최원준',
#   '구장': '구장 : 광주'},
#  {'날짜': '2024.05.16(목)',
#   '시작시간': '18:29',
#   '종료시간': '23:09',
#   '경기시간': '4:40',
#   '홈팀 선발': '윤영철',
#   '어웨이팀 선발': '김동주',
#   '구장': '구장 : 광주'},
#  {'날짜': '2024.05.17(금)',
#   '시작시간': '18:31',
#   '종료시간': '21:40',
#   '경기시간': '3:09',
#   '홈팀 선발': '최준호',
#   '어웨이팀 선발': '윌커슨',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.05.18(토)',
#   '시작시간': '17:00',
#   '종료시간': '20:04',
#   '경기시간': '3:04',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '나균안',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.05.19(일)',
#   '시작시간': '13:59',
#   '종료시간': '18:16',
#   '경기시간': '4:17',
#   '홈팀 선발': '브랜든',
#   '어웨이팀 선발': '이민석',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.05.21(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:31',
#   '경기시간': '3:01',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '이건욱',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.05.22(수)',
#   '시작시간': '18:30',
#   '종료시간': '21:32',
#   '경기시간': '3:02',
#   '홈팀 선발': '김민규',
#   '어웨이팀 선발': '김광현',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.05.23(목)',
#   '시작시간': '18:30',
#   '종료시간': '21:44',
#   '경기시간': '3:14',
#   '홈팀 선발': '최준호',
#   '어웨이팀 선발': '송영진',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.05.24(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:53',
#   '경기시간': '3:23',
#   '홈팀 선발': '황동하',
#   '어웨이팀 선발': '곽빈',
#   '구장': '구장 : 광주'},
#  {'날짜': '2024.05.25(토)',
#   '시작시간': '14:00',
#   '종료시간': '17:04',
#   '경기시간': '3:04',
#   '홈팀 선발': '양현종',
#   '어웨이팀 선발': '브랜든',
#   '구장': '구장 : 광주'},
#  {'날짜': '2024.05.26(일)',
#   '시작시간': '14:00',
#   '종료시간': '16:44',
#   '경기시간': '2:44',
#   '홈팀 선발': '네일',
#   '어웨이팀 선발': '알칸타라',
#   '구장': '구장 : 광주'},
#  {'날짜': '2024.05.28(화)',
#   '시작시간': '18:30',
#   '종료시간': '21:57',
#   '경기시간': '3:27',
#   '홈팀 선발': '최원준',
#   '어웨이팀 선발': '쿠에바스',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.05.29(수)',
#   '시작시간': '18:31',
#   '종료시간': '21:41',
#   '경기시간': '3:10',
#   '홈팀 선발': '최준호',
#   '어웨이팀 선발': '원상현',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.05.30(목)',
#   '시작시간': '18:30',
#   '종료시간': '21:17',
#   '경기시간': '2:47',
#   '홈팀 선발': '곽빈',
#   '어웨이팀 선발': '한차현',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.05.31(금)',
#   '시작시간': '18:30',
#   '종료시간': '21:57',
#   '경기시간': '3:27',
#   '홈팀 선발': '브랜든',
#   '어웨이팀 선발': '손주영',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.06.01(토)',
#   '시작시간': '17:00',
#   '종료시간': '21:02',
#   '경기시간': '4:02',
#   '홈팀 선발': '알칸타라',
#   '어웨이팀 선발': '켈리',
#   '구장': '구장 : 잠실'},
#  {'날짜': '2024.06.02(일)',
#   '시작시간': '14:00',
#   '종료시간': '17:37',
#   '경기시간': '3:37',
#   '홈팀 선발': '김유성',
#   '어웨이팀 선발': '엔스',
#   '구장': '구장 : 잠실'}]

# %%
dusan = pd.DataFrame(game_result)
dusan.구장 = dusan.구장.str[5:]
dusan
# Out:
#                 날짜   시작시간   종료시간  경기시간 홈팀 선발 어웨이팀 선발  구장
# 0    2022.04.02(토)  14:02  17:27  3:25    스탁     김민우  잠실
# 1    2022.04.03(일)  14:01  16:29  2:28   최원준      킹험  잠실
# 2    2022.04.05(화)  18:32  22:26  3:54   이영하     원태인  잠실
# 3    2022.04.06(수)  18:31  21:31  3:00    곽빈     양창섭  잠실
# 4    2022.04.07(목)  18:31  22:24  3:53   박신지     허윤동  잠실
# ..             ...    ...    ...   ...   ...     ...  ..
# 344  2024.05.29(수)  18:31  21:41  3:10   최준호     원상현  잠실
# 345  2024.05.30(목)  18:30  21:17  2:47    곽빈     한차현  잠실
# 346  2024.05.31(금)  18:30  21:57  3:27   브랜든     손주영  잠실
# 347  2024.06.01(토)  17:00  21:02  4:02  알칸타라      켈리  잠실
# 348  2024.06.02(일)  14:00  17:37  3:37   김유성      엔스  잠실
#
# [349 rows x 7 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '잠실'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 dusan[dusan['잠실']]
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: '잠실'

# %%
dusan.to_csv('./Data/dusan.csv', index=None)
pd.read_csv('./Data/dusan.csv')
# Out:
#                 날짜   시작시간   종료시간  경기시간 홈팀 선발 어웨이팀 선발  구장
# 0    2022.04.02(토)  14:02  17:27  3:25    스탁     김민우  잠실
# 1    2022.04.03(일)  14:01  16:29  2:28   최원준      킹험  잠실
# 2    2022.04.05(화)  18:32  22:26  3:54   이영하     원태인  잠실
# 3    2022.04.06(수)  18:31  21:31  3:00    곽빈     양창섭  잠실
# 4    2022.04.07(목)  18:31  22:24  3:53   박신지     허윤동  잠실
# ..             ...    ...    ...   ...   ...     ...  ..
# 344  2024.05.29(수)  18:31  21:41  3:10   최준호     원상현  잠실
# 345  2024.05.30(목)  18:30  21:17  2:47    곽빈     한차현  잠실
# 346  2024.05.31(금)  18:30  21:57  3:27   브랜든     손주영  잠실
# 347  2024.06.01(토)  17:00  21:02  4:02  알칸타라      켈리  잠실
# 348  2024.06.02(일)  14:00  17:37  3:37   김유성      엔스  잠실
#
# [349 rows x 7 columns]
